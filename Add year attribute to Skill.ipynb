# %%
import spacy
import random
import pickle
from spacy import displacy
import pandas as pd

# %%
df = pd.read_excel('Correlation_Link.xls')
skill_Set = set( list( df['node1'] ) + list( df['node2'] ) )
skill_Set = list(skill_Set)
skill_Set
# Out:
# ['HDFS',
#  'business intelligence',
#  'Apache Hadoop',
#  'DB2',
#  'Statistical Genetics',
#  'scripting',
#  'shell scripting',
#  'Oracle',
#  'MS Access',
#  'T-SQL',
#  'Inventory Planning',
#  'PySpark',
#  'C#',
#  'Microsoft Access',
#  'Jenkins',
#  'models',
#  'Mathematics',
#  'Data',
#  'databases',
#  'GitHub',
#  'C',
#  'CI/CD',
#  'BI',
#  'GLM/Regression',
#  'Business Analytics',
#  'jQuery',
#  'A/B testing',
#  'various groups',
#  'support',
#  'architecture',
#  'Google',
#  'algorithms',
#  'MS Azure',
#  'Google Analytics',
#  'tests',
#  'data pipelining',
#  'Hive/ Impala/ BigQuery',
#  'LSF',
#  'REACT JS',
#  'python',
#  'advanced analytics',
#  'neural networks',
#  'Predictive Modeling',
#  'Outlook',
#  'Database',
#  'Regression',
#  'Testing',
#  'R',
#  'Data Architect',
#  'Research',
#  'analytics',
#  'languages',
#  'data analysis',
#  'MS Office',
#  'HQL',
#  'Algorithms',
#  'Bugs',
#  'IoT',
#  'Matlab',
#  'NLTK',
#  'IBM DB2',
#  'Splunk',
#  'Data Warehousing',
#  'Looker',
#  'Tableau R',
#  'Epidemiology',
#  'C++',
#  'ArcGIS',
#  'Advanced Python',
#  'Data Scientist',
#  'Jupyter',
#  'confluence',
#  'Data Science',
#  'GCP',
#  'Microsoft Word',
#  'Data Modeling',
#  'Product Management',
#  'Microsoft',
#  'Postgres',
#  'deep learning algorithms',
#  'Plano',
#  'unit/integration testing',
#  'Periscopedata',
#  'MLLib',
#  'Economics',
#  'SharePoint',
#  'Perl',
#  'Technical Services',
#  'Service',
#  'LAN',
#  'MS Word',
#  'Kubernetes',
#  'data modeling',
#  'H2O',
#  'JavaScript',
#  'Teradata SQL',
#  'Gradient Boosting',
#  'BigQuery',
#  'Dask',
#  'Data Engineering',
#  'SQLite',
#  'ECS',
#  'data',
#  'Kinsesis',
#  'Sales',
#  'NOSQL',
#  'HR',
#  'CSS',
#  'Informatica',
#  'VB',
#  'Go',
#  'Vertica',
#  'AWS Redshift',
#  'skills',
#  'engineering',
#  'Hive',
#  'Caffe',
#  'Bethesda',
#  'Marketo',
#  'RDBMS',
#  'SQL Server',
#  'Machine',
#  'text mining',
#  'Assist sales',
#  'SPARK',
#  'Software Development',
#  'Athena',
#  'OpenShift',
#  'Data analysis',
#  'Stan',
#  'Networks',
#  'MySQL',
#  'Eclipse',
#  'marketing',
#  'SVN',
#  'Data analytics',
#  'Theano',
#  'MS PowerPoint',
#  'Python/R',
#  'PyTorch',
#  'systems engineering',
#  'Power Point',
#  'Operation Research',
#  'java',
#  'PowerPivot',
#  'Python',
#  'Data Engineer',
#  'simulations',
#  'EC2',
#  'Regression Analysis',
#  'Logistic Regression',
#  'TX',
#  'non-SQL',
#  'artificial intelligence',
#  'Modeling',
#  'Storm',
#  'Sagemaker',
#  'mysql',
#  'loading',
#  'Data Sciences',
#  'Data mining',
#  'Java',
#  'predictive analysis',
#  'Operations',
#  'MATLAB',
#  'feature engineering',
#  'machine',
#  'Kibana',
#  'regression analysis',
#  'optimization',
#  'Forecasting',
#  'Numerical Analysis',
#  'RDS',
#  'Decision Trees',
#  'Atlassian Jira',
#  'Pig',
#  'XML',
#  'statistical algorithms',
#  'Scripting',
#  'SageMaker',
#  'Visual Analytics',
#  'Microservices',
#  'Bitbucket',
#  'Map/Reduce',
#  'Deep Neural Networks',
#  'MA',
#  'multivariate testing',
#  'Java Script',
#  'JAVA',
#  'web analytics',
#  'Deep learning',
#  'Windows',
#  'Quality Assurance',
#  'Salesforce',
#  'EMR',
#  'Alteryx',
#  'statistical testing',
#  'Math',
#  'PostgreSQL',
#  'Flask',
#  'HTML5',
#  'HTML',
#  'Microsoft Azure',
#  'Gephi',
#  'advanced statistical analysis',
#  'systems',
#  'Engineering',
#  'Optimization',
#  'Neo4J',
#  'JIRA',
#  'Facebook',
#  'MSSQL',
#  'NoSQL',
#  'git',
#  'Predictive Analytics',
#  'Angular',
#  'Analytics',
#  'Project',
#  'Python R',
#  'Teradata',
#  'data blending',
#  'BitBucket',
#  'R Studio',
#  'Market Research',
#  'Azure',
#  'visualization',
#  'unit testing',
#  'Advanced Analytics',
#  'Data Mining',
#  'Pandas',
#  'Credit',
#  'ElasticSearch',
#  'Power BI',
#  'Tensorflow',
#  'Elasticsearch',
#  'TensorFlow',
#  'S3',
#  'Dallas',
#  'SVM',
#  'Azure Cognitive Services',
#  'statistical analysis',
#  'IT',
#  'MapReduce',
#  'Torch',
#  'Advertising',
#  'Data Management',
#  'VSTS',
#  'relational',
#  'Microsoft SQL',
#  'Analysis',
#  'svn',
#  'Qlik',
#  'Neural Networks',
#  'Automation',
#  'MD',
#  'Business Intelligence',
#  'MDX',
#  'PowerShell',
#  'logistic regression',
#  'hypothesis testing',
#  'Business Development',
#  'Excel',
#  'Industrial Engineering',
#  'Jupyter Notebooks',
#  'audit',
#  'Problem Solving',
#  'Marketing',
#  'statistical analytics',
#  'SSIS',
#  'Pytorch',
#  'tensorflow',
#  'testing',
#  'RedShift',
#  'Advanced knowledge',
#  'My SQL',
#  'NLP',
#  'Text Analytics',
#  'Python scripting',
#  'economics',
#  'Visual Basic',
#  'Regression analysis',
#  'MS SQL Server',
#  'AI',
#  'Statistical analysis',
#  'Neural Nets',
#  'Databricks',
#  'cloud computing',
#  'Data Administrators',
#  'MarkLogic',
#  'Advanced degree',
#  'Confluence',
#  'Software',
#  'Business',
#  'statistical modeling',
#  'Redshift',
#  'learning',
#  'Snowflake',
#  'Linux',
#  'noSQL',
#  'Mixpanel',
#  'Statistical Modeling',
#  'Google Cloud Platform',
#  'Cognos',
#  'POSTGRESQL',
#  'surveys',
#  'Statistical Analysis',
#  'Advanced Data Analytics',
#  'Golang',
#  'Cloud Computing',
#  'Julia',
#  'Jave',
#  'ETL',
#  'Creates',
#  'LaTeX',
#  'automation',
#  'Tableau',
#  'Spark ML',
#  'MS Excel',
#  'Data Wrangling',
#  'Architecture',
#  'Microsoft Visual Studio',
#  'AWS',
#  'Model Development',
#  'MongoDB',
#  'MS SQL',
#  'Econometrics',
#  'HiveSQL',
#  'Machine Learning',
#  'Big Data',
#  'PowerPoint',
#  'CS',
#  'Access',
#  'SAS',
#  'Ph',
#  'Map Reduce',
#  'Redis',
#  'Microsoft Reporting Studio',
#  'Jupyter Notebook',
#  'Jira',
#  'Scala',
#  'research',
#  'statistical learning',
#  'JMP',
#  'design',
#  'Data Analysis',
#  'Statistical Modelling',
#  'Database Design',
#  'MS',
#  'Lambda',
#  'Architect',
#  'Microsoft SQL Server',
#  'Html',
#  'XGBoost',
#  'The knowledge',
#  'Microsoft Excel',
#  'MXNet',
#  'Machine learning',
#  'math',
#  'Visio',
#  'PL/SQL',
#  'statistical software',
#  'Spark',
#  'A/B Testing',
#  'Javascript',
#  'software engineering',
#  'Digital Marketing',
#  'SQL',
#  'Cloud',
#  'Google Cloud',
#  'predictive modeling',
#  'Operational Research',
#  'Hadoop/HDFS',
#  'Docker',
#  'collaborative filtering',
#  'Data Scientists',
#  'social sciences',
#  'R/Python',
#  'Big SQL',
#  'text analytics',
#  'DynamoDB',
#  'Glue',
#  'Audit',
#  'data visualization',
#  'Feature Engineering',
#  'business analytics',
#  'Google BigQuery',
#  'computer science',
#  'Word',
#  'predictive analytics',
#  'Spotfire',
#  'data processing',
#  'MatLab',
#  'Nompy',
#  'forecasting/predictive analytics',
#  'Visualization',
#  'database',
#  'Deep Learning',
#  'Programming',
#  'Data Analytics',
#  'Github',
#  'PHP',
#  'Intelligence',
#  'software development',
#  'Base SAS',
#  'machine learning',
#  'Ruby',
#  'Mahout',
#  'relational databases',
#  'Kafka',
#  'Adobe Analytics',
#  'Data Visualization',
#  'Hadoop',
#  'sales',
#  'dashboards',
#  'Django',
#  'Computer Sciences',
#  'finance',
#  'DevOps',
#  'Oracle JavaScript',
#  'Artificial Intelligence',
#  'statistical data analytics',
#  'unsupervised learning',
#  'Operations Research',
#  'Linear',
#  'J2EE',
#  'Equity',
#  'Statistics',
#  'Finance',
#  'Apache Spark',
#  'Design',
#  'Statistical modeling',
#  'Cognitive Computing',
#  'software',
#  'statistics',
#  'data analytics',
#  'SAP Hana',
#  'deep learning',
#  'Product Development',
#  'SPSS',
#  'Scikit-Learn',
#  'Keras',
#  'Kinesis',
#  'Risk Analysis',
#  'analysis',
#  'Git',
#  'GIT',
#  'Technology',
#  'CVS']

# %%
model = spacy.load ( 'en_core_web_sm' )
# ner_model = spacy.load('ner_model/')

# %% [markdown]
# # import sentence contains DATE

# %%
with open('demo.pkl','rb') as out_data:
    data=pickle.load(out_data)

for sentence in data[:10]:
    print('-'*120)
    print(sentence)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# accurate status of projects aligned with the methodology being used (SCRUM/Iterative/ Waterfall)            Carry a Tier-2 support pager on a 6  8 week rotation           Support, maintenance, and development of JAVA web based and stand-alone applications
# ------------------------------------------------------------------------------------------------------------------------
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
# ------------------------------------------------------------------------------------------------------------------------
# - Minimum of 4-6 years working experience with Java/Unix/Oracle-based development.
# ------------------------------------------------------------------------------------------------------------------------
# accurate status of projects aligned with the methodology being used (SCRUM/Iterative/ Waterfall)            Carry a Tier-2 support pager on a 6  8 week rotation           Support, maintenance, and development of JAVA web based and stand-alone applications
# ------------------------------------------------------------------------------------------------------------------------
# 5 years web development experience on J2EE -Minimum 5 years experience in working within a web development team
# ------------------------------------------------------------------------------------------------------------------------
# 5 years experience with web portal usability analysis and testing.
# ------------------------------------------------------------------------------------------------------------------------
# development experience with JSF, Servlets, JSP, JSTL, and IceFaces, and Velocity templates -3 years professional experience in developing web-services for the web consumption.
# ------------------------------------------------------------------------------------------------------------------------
#  6 years experience programming Core Java, JSP and J2EE technologies.
# ------------------------------------------------------------------------------------------------------------------------
# (1+ years) experience using Spring and Spring MVC.
# ------------------------------------------------------------------------------------------------------------------------
# Somers, NY  Length: 6 Months Employment Type: Contract  Job Description Advanced Java Developer needed for special project in Somers New York.

# %% [markdown]
# # take a sentence plot dependency tree

# %%
def get_Date_attribute( string ):
    print( string )
    doc = model( string )

    print( [ token for token in doc.ents] )
    displacy.render(doc, style='dep', jupyter=True)
    
    print( [ token for token in doc.ents if token.root.ent_type_ == 'DATE' and 'year' in token.root.text ] )

# %%
# import random

sentence = data[ random.randint(0, len(data) ) ]
get_Date_attribute( sentence )
# Out:
# Terms of Reference: 5 Month Contract, possible extension  Participate in the team to integrate off the shelf ICAM related products to provide on cohesive ICAM shared service infrastructure for institutional and departmental applications.
# [5 Month, Participate, ICAM, ICAM]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b2e93a6f49734b909a9d9d66883fd83b-0" class="displacy" width="6175" height="924.5" direction="ltr" style="max-width: none; height: 924.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Terms</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Reference:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">Month</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Contract,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">possible</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">extension</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Participate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">team</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">integrate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">off</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">shelf</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">ICAM</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">related</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">products</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">provide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">cohesive</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">ICAM</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">shared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">service</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">infrastructure</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="834.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">institutional</tspan>
#     <tspan class="displacy-
# []

# %%
# import random

sentence = data[ random.randint(0, len(data) ) ]
get_Date_attribute( sentence )
# Out:
# Tampa, FL Duration: 12 Months (with high possibility of extension)
# [Tampa, 12 Months]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b4b85c0b6a7b4ebca0922f6ebf0a6467-0" class="displacy" width="2150" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Tampa,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">FL</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Duration:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">12</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">Months (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">high</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">possibility</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">extension)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">SPACE</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-0" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-1" stroke-width="2px" d="M70,439.5 C70,264.5 385.0,264.5 385.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385.0,441.5 L393.0,429.5 377.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-2" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M555.0,441.5 L563.0,429.5 547.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-3" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-4" stroke-width="2px" d="M70,439.5 C70,177.0 915.0,177.0 915.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,441.5 L923.0,429.5 907.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-5" stroke-width="2px" d="M70,439.5 C70,89.5 1095.0,89.5 1095.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,441.5 L1103.0,429.5 1087.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-6" stroke-width="2px" d="M1295,439.5 C1295,352.0 1430.0,352.0 1430.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,441.5 L1287,429.5 1303,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-7" stroke-width="2px" d="M1120,439.5 C1120,264.5 1435.0,264.5 1435.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b4b85c0b6a7b4ebca0922f6ebf0a6467-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1435.0,441.5 L1443.0,429.5 1427.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displ
# []

# %%
# import random
# sentence = data[ random.randint(0, len(data) ) ]

sentence = 'SQL and RDBMS experience of at least two years.'
sentence = '3+ years scripting experience: BASH, Perl, Python, Ruby, etc.'
sentence = '(Minimum of 3 years exp), UNIX (3+ years), general SQL '
sentence = '6 years experience programming Core Java, JSP and J2EE technologies.'
get_Date_attribute( sentence )
# Out:
# 6 years experience programming Core Java, JSP and J2EE technologies.
# [6 years, Core Java, JSP, J2EE]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e64f2d9148fc427b909d64d74bf91274-0" class="displacy" width="1800" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">6</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">experience</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">programming</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Core</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Java,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">JSP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">J2EE</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">technologies.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-2" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-3" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-4" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-5" stroke-width="2px" d="M945,352.0 C945,2.0 1625.0,2.0 1625.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-6" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-7" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1260.0,354.0 L1268.0,342.0 1252.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e64f2d9148fc427b909d64d74bf91274-0-8" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e64f2d9148fc427b909d64d74bf91274-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowh
# [6 years]

# %%
def is_father( word, root ):
    if word == root:
        return True
    
    while word != word.head:
        word = word.head
        if word == root:
            return True
    
    return False

# %% [markdown]
# # Link year attribute to entity

# %%
# sentence = '2+ years working in an Agile environment'
# sentence ='years experience with Java development'
# sentence = 'This candidate needs to have 3-5 years of Java development experience, J2EE experience, Spring, and Hibernate experience.'
# sentence = '2 years experience developing service-oriented (SOA) architectures and EAI technologies such as Tibco'
# sentence = 'Java application development experience  Must have 3+ years'

# sentence = 'Minimum 5 years experience in working within a web development team'
sentence = '3+ years experience of Java application development'
# sentence = data[ random.randint(0, len(data) ) ]
get_Date_attribute( sentence )

doc = model( sentence )
print( [ent for ent in doc.ents] )

date_list = []
for tem in doc.ents:
    if tem.root.ent_type_ == 'DATE' and 'year' in tem.root.text:
        date_list.append( tem )
print( 'date_list:', date_list )
        
    
tem_list = []
for tem in doc.ents:
    if tem.root.ent_type_ != 'DATE':
        tem_list.append( tem )
print( 'tem_list:', tem_list)


for date in date_list:
    print( 'date_list:',date )
    Date = date

    for tem in tem_list:
        Flag = False
        
        if is_father( tem.root, Date.root ):
            print( tem ,'-->' , Date )
            Flag = True

        if Flag == False:
            Date_Head = Date.root

            if Date_Head.dep_ == 'compound':
                Date_Head = Date_Head.head
#                 print( 'Date_Head',Date_Head )
        #         if Date.tag_ == 'NOUN':
        #             Flag = False
                if is_father( tem.root, Date_Head ):
                    print( tem ,'-->' , Date )
                    Flag = True
                    
            
            Date_Head = Date.root
            while !Flag and Date_Head != Date_Head.head:
                Date_Head = Date_Head.head
                
                if is_father( tem.root, Date_Head ):
                    print( tem ,'-->' , Date )
# Out:
#   File "<ipython-input-196-e4cc099e485f>", line 54
#     while !Flag and Date_Head != Date_Head.head:
#           ^
# SyntaxError: invalid syntax

# %%
# sentence = '2+ years working in an Agile environment'
# sentence ='years experience with Java development'
# sentence = 'This candidate needs to have 3-5 years of Java development experience, J2EE experience, Spring, and Hibernate experience.'
# sentence = '2 years experience developing service-oriented (SOA) architectures and EAI technologies such as Tibco'
# sentence = 'Java application development experience  Must have 3+ years'

# sentence = 'Minimum 5 years experience in working within a web development team'
# sentence = '3+ years experience of Java application development'

sentence = data[ random.randint(0, len(data) ) ]
get_Date_attribute( sentence )

doc = model( sentence )
print( [ent for ent in doc.ents] )

date_list = []
for tem in doc.ents:
    if tem.root.ent_type_ == 'DATE' and 'year' in tem.root.text:
        date_list.append( tem )
print( 'date_list:', date_list )
        
    
tem_list = []
for tem in doc.ents:
    if tem.root.ent_type_ != 'DATE':
        tem_list.append( tem )
print( 'tem_list:', tem_list)


for date in date_list:
    Date = date

    for tem in tem_list:
        Flag = False
        
        if is_father( tem.root, Date.root ):
            print( tem ,'-->' , Date )
            Flag = True

        if Flag == False:
            Date_Head = Date.root

            if Date_Head.dep_ == 'compound':
                Date_Head = Date_Head.head
#                 print( 'Date_Head',Date_Head )
        #         if Date.tag_ == 'NOUN':
        #             Flag = False
                if is_father( tem.root, Date_Head ):
                    print( tem ,'-->' , Date )
                    Flag = True
                    
            
            Date_Head = Date.root
            while Flag == False and Date_Head != Date_Head.head:
                Date_Head = Date_Head.head
                
                if Date_Head.tag_ == 'NOUN' and is_father( tem.root, Date_Head ):
                    print( tem ,'-->' , Date )
                    Flag = True
                    
                if Date_Head.tag_ == 'NOUN':
                    break
# Out:
# Qualified candidates are required:  - 1 - 3 years as a software developer with some or all of the following technologies: Java, J2EE, JSP, Servlets, JDBC; HTML, JavaScript, CSS; XML, XSD, XSLT - Experience with Agile with Scrum software development methodologies are highly desired - Development skills to include design, development, testing, deployment and support.
# [1 - 3 years, Java, J2EE, JSP, Servlets, JDBC, JavaScript, XML, XSD, Scrum]
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d3c5fb04b7ad43b4986b109f3521d176-0" class="displacy" width="9150" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Qualified</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">candidates</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">required:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750"> -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">1 -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">3</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">software</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">developer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">all</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">following</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">technologies:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Java,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">J2EE,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">JSP,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Servlets,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">JDBC;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">HTML,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">JavaScript,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">CSS;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">XML,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">XSD,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">XSLT -</tspan>
#     <tspan class="displacy-tag" dy
# [1 - 3 years]
# [1 - 3 years, Java, J2EE, JSP, Servlets, JDBC, JavaScript, XML, XSD, Scrum]
# date_list: [1 - 3 years]
# tem_list: [Java, J2EE, JSP, Servlets, JDBC, JavaScript, XML, XSD, Scrum]
# Java, J2EE --> 1 - 3 years
# JSP --> 1 - 3 years
# Servlets --> 1 - 3 years
# JDBC --> 1 - 3 years
# JavaScript --> 1 - 3 years
# XML --> 1 - 3 years
# XSD --> 1 - 3 years
# Scrum --> 1 - 3 years

# %% [markdown]
# # testing

# %%
for sentence in data:
    print( '=' * 120 )
    print( 'SENTENCE:' )
    print( sentence )
    
    print()
    print( 'OUTPUT:' )
    doc = model( sentence )
#     print( [ent for ent in doc.ents] )

    date_list = []
    for tem in doc.ents:
        if tem.root.ent_type_ == 'DATE' and 'year' in tem.root.text:
            date_list.append( tem )
    print( 'date_list:', date_list )


    tem_list = []
    for tem in doc.ents:
        if tem.root.ent_type_ != 'DATE':
            tem_list.append( tem )
    print( 'tem_list:', tem_list)
    print()

    for date in date_list:
        Date = date

        for tem in tem_list:
            Flag = False

            if is_father( tem.root, Date.root ):
                print( tem ,'-->' , Date )
                Flag = True

            if Flag == False:
                Date_Head = Date.root

                if Date_Head.dep_ == 'compound':
                    Date_Head = Date_Head.head
    #                 print( 'Date_Head',Date_Head )
            #         if Date.tag_ == 'NOUN':
            #             Flag = False
                    if is_father( tem.root, Date_Head ):
                        print( tem ,'-->' , Date )
                        Flag = True


                Date_Head = Date.root
                while Flag == False and Date_Head != Date_Head.head:
                    Date_Head = Date_Head.head

                    if Date_Head.tag_ == 'NOUN' and is_father( tem.root, Date_Head ):
                        print( tem ,'-->' , Date )
                        Flag = True

                    if Date_Head.tag_ == 'NOUN':
                        break
# Out:
# ========================================================================================================================
# SENTENCE:
# accurate status of projects aligned with the methodology being used (SCRUM/Iterative/ Waterfall)            Carry a Tier-2 support pager on a 6  8 week rotation           Support, maintenance, and development of JAVA web based and stand-alone applications
#
# OUTPUT:
# date_list: []
# tem_list: [6, JAVA]
#
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# - Minimum of 4-6 years working experience with Java/Unix/Oracle-based development.
#
# OUTPUT:
# date_list: [4-6 years]
# tem_list: [Java/Unix/Oracle]
#
# ========================================================================================================================
# SENTENCE:
# accurate status of projects aligned with the methodology being used (SCRUM/Iterative/ Waterfall)            Carry a Tier-2 support pager on a 6  8 week rotation           Support, maintenance, and development of JAVA web based and stand-alone applications
#
# OUTPUT:
# date_list: []
# tem_list: [6, JAVA]
#
# ========================================================================================================================
# SENTENCE:
# 5 years web development experience on J2EE -Minimum 5 years experience in working within a web development team
#
# OUTPUT:
# date_list: [5 years, 5 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# 5 years experience with web portal usability analysis and testing.
#
# OUTPUT:
# date_list: [5 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# development experience with JSF, Servlets, JSP, JSTL, and IceFaces, and Velocity templates -3 years professional experience in developing web-services for the web consumption.
#
# OUTPUT:
# date_list: [years]
# tem_list: [JSF, Servlets, JSP, JSTL, IceFaces, Velocity]
#
# ========================================================================================================================
# SENTENCE:
#  6 years experience programming Core Java, JSP and J2EE technologies.
#
# OUTPUT:
# date_list: [6 years]
# tem_list: [Core Java, JSP, J2EE]
#
# ========================================================================================================================
# SENTENCE:
# (1+ years) experience using Spring and Spring MVC.
#
# OUTPUT:
# date_list: []
# tem_list: [Spring]
#
# ========================================================================================================================
# SENTENCE:
# Somers, NY  Length: 6 Months Employment Type: Contract  Job Description Advanced Java Developer needed for special project in Somers New York.
#
# OUTPUT:
# date_list: []
# tem_list: [Somers New York]
#
# ========================================================================================================================
# SENTENCE:
# For more than 27 years, MATRIX has placed talented contract and permanent IT professionals like yourself at thousands of top-notch organizations throughout the U.S., ranging from Fortune 50 to small IT shops across all industries.
#
# OUTPUT:
# date_list: [more than 27 years]
# tem_list: [MATRIX, thousands, U.S., Fortune 50]
#
# ========================================================================================================================
# SENTENCE:
# Apply today at MATRIX.
#
# OUTPUT:
# date_list: []
# tem_list: [MATRIX]
#
# ========================================================================================================================
# SENTENCE:
# Investacorp Inc. is a Securities Broker Dealer with over 30 years in business.
#
# OUTPUT:
# date_list: [30 years]
# tem_list: [Investacorp Inc.]
#
# ========================================================================================================================
# SENTENCE:
# If you have 1+ year of experience with Java doing maintenance and enhancements, please contact Gabe Molstre at 515.282.6876 or gabe.molstre@rht.com.
#
# OUTPUT:
# date_list: [1+ year]
# tem_list: [Java, Gabe Molstre]
#
# Java --> 1+ year
# ========================================================================================================================
# SENTENCE:
# If you are qualified and interested in this position, please apply online today for consideration.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Mandatory Skill Set: - SQL (SQL Server 2005 / 2008, Oracle, Enterprise DB, etc.)
#
# OUTPUT:
# date_list: []
# tem_list: [SQL, SQL, Oracle, Enterprise DB]
#
# ========================================================================================================================
# SENTENCE:
# - Mush have a thorough knowledge of software engineering principles - Java 1.5/1.6 - J2EE/EJB - SQL (SQL Server 2005 / 2008, Oracle, Enterprise DB, etc.)
#
# OUTPUT:
# date_list: []
# tem_list: [- Mush, SQL, Oracle, Enterprise DB]
#
# ========================================================================================================================
# SENTENCE:
# - 7+ years experience                 Join TEKsystems
#
# OUTPUT:
# date_list: [7+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# * 5 to 10 plus years of direct work related experience
#
# OUTPUT:
# date_list: [5 to 10 plus years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Proficient knowledge of the Spring framework, and Java or .Net
#
# OUTPUT:
# date_list: []
# tem_list: [Java]
#
# ========================================================================================================================
# SENTENCE:
# Call today and learn more about our referral program.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Must have working demonstrated knowledge of: Java (at least 4 years) Perl and regular expressions ( 2 years) SQL (MySQL specifically) Unix/Linux environment Maven - general usage - XML – HTML Java Script - PHP (1 year)
#
# OUTPUT:
# date_list: [at least 4 years, 2 years, 1 year]
# tem_list: [Java, Perl, SQL, Java Script - PHP]
#
# ========================================================================================================================
# SENTENCE:
# Contract     TEKsystems has partnered with a local government integrator to support their need for a Java developer with 3-5 years of experience working in a J2EE environment.
#
# OUTPUT:
# date_list: [3-5 years]
# tem_list: [Java, J2EE]
#
# J2EE --> 3-5 years
# ========================================================================================================================
# SENTENCE:
# Mandatory Requirements: 1-3 years experience with Java / J2EE technologiesExperience with a wide range of tools and technologies with a focus on Java/J2EE technologies, including WebSphere, Tomcat, RAD/Eclipse,Struts 2 and Hibernate.
#
# OUTPUT:
# date_list: [1-3 years]
# tem_list: [Java / J2EE, Java/J2EE, WebSphere, Tomcat, Eclipse, 2]
#
# Java / J2EE --> 1-3 years
# Java/J2EE --> 1-3 years
# WebSphere --> 1-3 years
# Tomcat --> 1-3 years
# Eclipse --> 1-3 years
# 2 --> 1-3 years
# ========================================================================================================================
# SENTENCE:
# A well-qualified candidate for the Java Developer position will possess all of the following:  - 5+ years in C++ and web development experience (and experience with some of the Java frameworks; Struts, Spring, Eclipse, EXTJS, etc. )
#
# OUTPUT:
# date_list: []
# tem_list: [Java Developer, C++, Java, Struts, Spring, Eclipse, EXTJS]
#
# ========================================================================================================================
# SENTENCE:
# We know it''s more than just your day-to-day responsibilities that can make or break a job.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# A large client in the Triad area of NC is looking for a Senior level Java developer for a 6 month extendable contract engagement.
#
# OUTPUT:
# date_list: []
# tem_list: [Triad, NC, Java]
#
# ========================================================================================================================
# SENTENCE:
# In addition, a minimum of 2 years of relevant experience is required.
#
# OUTPUT:
# date_list: [2 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Must have a minimum of 5 years experience in COTS integration, Java, HTML, web development, and
#
# OUTPUT:
# date_list: [5 years]
# tem_list: [Java]
#
# ========================================================================================================================
# SENTENCE:
# SImilar products to this are TIBCO, IBM Datapower, or Webmethods.
#
# OUTPUT:
# date_list: []
# tem_list: [TIBCO, IBM]
#
# ========================================================================================================================
# SENTENCE:
#  Heartland was founded in 1997 and is the 5th largest credit, debit, payroll and related processing service provider in the United States with over 3000 employees in operations, sales, IT, marketing and administration.
#
# OUTPUT:
# date_list: []
# tem_list: [Heartland, 5th, the United States, 3000]
#
# ========================================================================================================================
# SENTENCE:
# Kforce Technology has been helping Saint Louis Information Technology Professionals reach their career goals in contract and direct-hire positions for over 30 years.
#
# OUTPUT:
# date_list: [over 30 years]
# tem_list: [Kforce Technology, Saint Louis Information Technology Professionals]
#
# ========================================================================================================================
# SENTENCE:
# • 3 years experience with Java/J2EE Development  • 2 years experience with application servers –
#
# OUTPUT:
# date_list: [3 years, 2 years]
# tem_list: [Java/J2EE Development]
#
# Java/J2EE Development --> 3 years
# Java/J2EE Development --> 2 years
# ========================================================================================================================
# SENTENCE:
# Glassfish preferred  • 1 year experience in Web-Services Development  • 1 year experience with EJB, JMS, XML, JDBC  • Experience with version and change control software  • Experience with object-oriented design and analysis  DESIRED SKILLS  • CMMI
#
# OUTPUT:
# date_list: [1 year, 1 year]
# tem_list: [Glassfish, Web-Services Development, EJB, JMS, XML, JDBC, CMMI]
#
# Web-Services Development --> 1 year
# EJB --> 1 year
# JMS --> 1 year
# XML --> 1 year
# JDBC --> 1 year
# EJB --> 1 year
# JMS --> 1 year
# XML --> 1 year
# JDBC --> 1 year
# ========================================================================================================================
# SENTENCE:
# Our client a prominent government integrator is looking for a Java Developer in support of a government customer    Required Skills: 2-4 years of hands-on experience performing  development in a J2EE
#
# OUTPUT:
# date_list: [2-4 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# We know it''s more than just your day-to-day responsibilities that can make or break a job.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Java Developer  Are you a Java Developer and have over 2 years of experience?
#
# OUTPUT:
# date_list: [2 years]
# tem_list: [Java Developer]
#
# ========================================================================================================================
# SENTENCE:
# Essential Skills: -- 2-4 years of experience in web based application support (troubleshooting, root cause analysis, code modification).
#
# OUTPUT:
# date_list: [2-4 years]
# tem_list: [Essential Skills]
#
# ========================================================================================================================
# SENTENCE:
# -- 1-3 years of experience in web application development, specifically Java, JSP and JDBC.
#
# OUTPUT:
# date_list: [1-3 years]
# tem_list: [Java, JSP, JDBC]
#
# Java --> 1-3 years
# JSP --> 1-3 years
# JDBC --> 1-3 years
# ========================================================================================================================
# SENTENCE:
# 1-3 years Java development and object oriented programming experience Must have some knowledge and understanding of SQL Experience with Linux
#
# OUTPUT:
# date_list: [1-3 years]
# tem_list: [Java, SQL]
#
# ========================================================================================================================
# SENTENCE:
# This position supports one of Dell's largest commercial account with annual revenues of $14.1 billion and more than 70,000 employees and operates more than 1.2 million cars and trucks, making it the largest car rental service provider in the world measured by revenue, employees and fleet.
#
# OUTPUT:
# date_list: []
# tem_list: [Dell, $14.1 billion, more than 70,000, more than 1.2 million]
#
# ========================================================================================================================
# SENTENCE:
#  The R&D Team at Dealer.com has spent over a decade building an award-winning web platform and innovative internet marketing software and is recognized by industry experts and our clients as a global leader in the automotive industry.
#
# OUTPUT:
# date_list: []
# tem_list: [The R&D Team, Dealer.com]
#
# ========================================================================================================================
# SENTENCE:
# Design, develop and maintain web-based applications to enhance the performance and reliability of our current applications, as well as participate in the development of new industry-leading products, leveraging technologies such as Spring, Grails, MySQL, Coherence, Solr, MongoDB, RabbitMQ,etc.
#
# OUTPUT:
# date_list: []
# tem_list: [Grails, Coherence]
#
# ========================================================================================================================
# SENTENCE:
#  Our client is looking for a Java Developer for a 12 month project to start in mid April in Sacramento, CA.
#
# OUTPUT:
# date_list: []
# tem_list: [Sacramento, CA]
#
# ========================================================================================================================
# SENTENCE:
# B.            Experience with programming automated systems that support the general and typical business functions of management reporting, accounting, and document printing; and our specialized system functions dealing with program set up, application and contract processing, and related financial transactions, monitoring and reconciliation would be considered pluses C.            Ability to add, modify, and enhance an application while maintaining the existing architecture of the application D.            Strong experience in Object Oriented Programming (OOP) design and analysis principles E.            Oracle Java Programmer Certification; or at least 6 years experience with Java F.            Strong background and work experience in developing J2EE applications with emphasis on Struts, JSP and JAVA Servlets G.            JAVA Standard Tag Library (JSTL)
#
# OUTPUT:
# date_list: [at least 6 years]
# tem_list: [C.            Ability, D., OOP, E., Oracle Java Programmer Certification, Java F.            Strong, J2EE, Struts, JSP, JAVA Servlets, JSTL]
#
# Java F.            Strong --> at least 6 years
# J2EE --> at least 6 years
# Struts --> at least 6 years
# JSP --> at least 6 years
# JAVA Servlets --> at least 6 years
# JSTL --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# The Java Developer will be responsible for the Java and Web teams that will design, code, modify, test, debug, document, install, deploy and support daily operations for a set of applications in the in the Healthcare Insurance industry.
#
# OUTPUT:
# date_list: []
# tem_list: [The Java Developer, Java, Web]
#
# ========================================================================================================================
# SENTENCE:
# + years development experience with Java, JavaScript, Spring, JSP, Hibernate, JDBC, XML, SOAP/REST & WebLogic, Oracle & MS SQL Server    •5
#
# OUTPUT:
# date_list: [years]
# tem_list: [Java, JavaScript, JSP, JDBC, XML, SOAP/REST & WebLogic, Oracle & MS SQL]
#
# Java --> years
# JavaScript --> years
# JSP --> years
# JDBC --> years
# XML --> years
# SOAP/REST & WebLogic --> years
# Oracle & MS SQL --> years
# ========================================================================================================================
# SENTENCE:
# Founded in 1976, CGI is a leading IT and business process services firm committed to helping clients succeed.
#
# OUTPUT:
# date_list: []
# tem_list: [CGI]
#
# ========================================================================================================================
# SENTENCE:
# Benefits for full-time, permanent members start on the first day of employment and include a paid time-off program and profit participation and stock purchase plans.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# The mid level Java Developer  is responsible for performing analysis, modification, documentation and support of daily operations for the ERP system and other applications.
#
# OUTPUT:
# date_list: []
# tem_list: [Java Developer, ERP]
#
# ========================================================================================================================
# SENTENCE:
# • May use computer-aided software tools in each stage of system development
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# • 3+ Years
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Founded in 1976, CGI is a leading IT and business process services firm committed to helping clients succeed.
#
# OUTPUT:
# date_list: []
# tem_list: [CGI]
#
# ========================================================================================================================
# SENTENCE:
# Benefits for full-time, permanent members start on the first day of employment and include a paid time-off program and profit participation and stock purchase plans.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Java Developer  Are you a Java Developer and have over 2 years of experience?
#
# OUTPUT:
# date_list: [2 years]
# tem_list: [Java Developer]
#
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# * 8+ years software development.
#
# OUTPUT:
# date_list: [8+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Please let me know if you have experience in spring, hibernate, agile, and web services.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# One of the position requires Spring, Hibernate, and Agile for a 6 month contract to hire position.
#
# OUTPUT:
# date_list: []
# tem_list: [One]
#
# ========================================================================================================================
# SENTENCE:
# Over the past year, we have more than doubled our technical staff and we are still growing!
#
# OUTPUT:
# date_list: [the past year]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# The VBMS program is a multi-year effort to transition the current paper-based Veterans claims process to a paperless solution which will reduce the average time for veteran benefits claim processing, reduce the number of claims in the VBA backlog, and automate claims tracking.
#
# OUTPUT:
# date_list: [multi-year]
# tem_list: [VBMS, Veterans, VBA]
#
# ========================================================================================================================
# SENTENCE:
# This experience must include: - Six years of experience in Business IT/C2 Support Systems.
#
# OUTPUT:
# date_list: [Six years]
# tem_list: [Business IT/C2 Support Systems]
#
# Business IT/C2 Support Systems --> Six years
# ========================================================================================================================
# SENTENCE:
# - Three years direct experience with UNIX, SYBASE, Windows and/or LINUX.
#
# OUTPUT:
# date_list: [Three years]
# tem_list: [UNIX]
#
# ========================================================================================================================
# SENTENCE:
# Bachelors Degree or equivalent experience and a minimum of 1 year of directly related work experience required.
#
# OUTPUT:
# date_list: [1 year]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Founded in 1976, CGI is a leading IT and business process services firm committed to helping clients succeed.
#
# OUTPUT:
# date_list: []
# tem_list: [CGI]
#
# ========================================================================================================================
# SENTENCE:
# Benefits for full-time, permanent members start on the first day of employment and include a paid time-off program and profit participation and stock purchase plans.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# This developer position will primarily be engaged in day to day development on website enhancements.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# - Experience on eCommerce & public customer facing web applications w/high transactional volume Excellent Java and SQL skills (4+ years)
#
# OUTPUT:
# date_list: [4+ years]
# tem_list: [eCommerce &, Excellent Java, SQL]
#
# ========================================================================================================================
# SENTENCE:
# - Ability to write queries directly via JDBC - Experience with JSPs - Strong with common web technologies (6+ years) - HTML - CSS - Javascript - XML - Web services - AJAX - Various web browsers - Prefer Oracle DB experience - Strong with common web standards and best practices - SEO - Usability - Analytics and tracking - Integration with 3rd party vendors   •*Tools they Use (experience in these is a PLUS)
#
# OUTPUT:
# date_list: [6+ years]
# tem_list: [JDBC, AJAX, 3rd party]
#
# ========================================================================================================================
# SENTENCE:
#  Our client is looking for a Java Developer for a 12 month project to start in mid April in Sacramento, CA.
#
# OUTPUT:
# date_list: []
# tem_list: [Sacramento, CA]
#
# ========================================================================================================================
# SENTENCE:
# B.            Experience with programming automated systems that support the general and typical business functions of management reporting, accounting, and document printing; and our specialized system functions dealing with program set up, application and contract processing, and related financial transactions, monitoring and reconciliation would be considered pluses C.            Ability to add, modify, and enhance an application while maintaining the existing architecture of the application D.            Strong experience in Object Oriented Programming (OOP) design and analysis principles E.            Oracle Java Programmer Certification; or at least 6 years experience with Java F.            Strong background and work experience in developing J2EE applications with emphasis on Struts, JSP and JAVA Servlets G.            JAVA Standard Tag Library (JSTL)
#
# OUTPUT:
# date_list: [at least 6 years]
# tem_list: [C.            Ability, D., OOP, E., Oracle Java Programmer Certification, Java F.            Strong, J2EE, Struts, JSP, JAVA Servlets, JSTL]
#
# Java F.            Strong --> at least 6 years
# J2EE --> at least 6 years
# Struts --> at least 6 years
# JSP --> at least 6 years
# JAVA Servlets --> at least 6 years
# JSTL --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# Duration: 3 - 6 Months contract to permanent  Location: King of Prussia, PA  Job Description:
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# 7+ years experience working in a Java/J2EE Development capacity.
#
# OUTPUT:
# date_list: [7+ years]
# tem_list: [Java/J2EE Development]
#
# Java/J2EE Development --> 7+ years
# ========================================================================================================================
# SENTENCE:
# 2+ years experience in webMethods or the use of similar tools for B2B integration projects.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Years of experience = 2-4+ years.
#
# OUTPUT:
# date_list: [2-4+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Required Skills  - Minimum of 5+ years
#
# OUTPUT:
# date_list: [5+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# We have a 6 month contract in Paramus, NJ for a Java Developer.
#
# OUTPUT:
# date_list: []
# tem_list: [Paramus]
#
# ========================================================================================================================
# SENTENCE:
# The candidate must have a minimum 5-7 years of Java and J2EE  •Experience working with HTML/CSS/JavaScript  •Strong with JSP/Servlets/J2ee technology
#
# OUTPUT:
# date_list: [5-7 years]
# tem_list: [Java, J2EE, HTML/CSS/JavaScript, •Strong, JSP/Servlets/J2ee]
#
# Java --> 5-7 years
# J2EE --> 5-7 years
# ========================================================================================================================
# SENTENCE:
# Must Haves: Eligibility to be cleared to Secret Clearance Bachelor's Degree in Computer Science or Engineering 6 Years of Java Development experience   •*BECAUSE
#
# OUTPUT:
# date_list: []
# tem_list: [Secret Clearance Bachelor's, Java Development]
#
# ========================================================================================================================
# SENTENCE:
# Contract     TEKsystems has partnered with a local government integrator to support their need for a Java developer with 2-3 years of experience working in a J2EE environment.
#
# OUTPUT:
# date_list: [2-3 years]
# tem_list: [Java, J2EE]
#
# J2EE --> 2-3 years
# ========================================================================================================================
# SENTENCE:
# Bachelor’s degree and 1+ years experience, or 7.
#
# OUTPUT:
# date_list: [1+ years]
# tem_list: [7]
#
# 7 --> 1+ years
# ========================================================================================================================
# SENTENCE:
# 3+ years experience in a related field 8.
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [8]
#
# 8 --> 3+ years
# ========================================================================================================================
# SENTENCE:
# Comprehensive benefits package w/ up to 14 days time off 14.
#
# OUTPUT:
# date_list: []
# tem_list: [14]
#
# ========================================================================================================================
# SENTENCE:
#   10 month contract in Chicago for a Java web Developer  Job Summary:  Seeking a Java/J2EE Developer to serve as a key member of our development team.
#
# OUTPUT:
# date_list: []
# tem_list: [Chicago, Java, Java]
#
# ========================================================================================================================
# SENTENCE:
# The ideal candidate will have 5-10 years of strong background developing complex web applications using Java/J2EE technologies as well as Oracle.
#
# OUTPUT:
# date_list: [5-10 years]
# tem_list: [Java/J2EE, Oracle]
#
# Java/J2EE --> 5-10 years
# Oracle --> 5-10 years
# ========================================================================================================================
# SENTENCE:
# Years of strong experience working with Oracle SQL  - Preferable 2+ years of Oracle PL/SQL development experience  - Experience of working with JMS implementations & Knowledge of Websphere MQ.
#
# OUTPUT:
# date_list: [2+ years]
# tem_list: [SQL, Oracle PL/SQL, JMS implementations & Knowledge, Websphere MQ]
#
# SQL --> 2+ years
# Oracle PL/SQL --> 2+ years
# JMS implementations & Knowledge --> 2+ years
# Websphere MQ --> 2+ years
# ========================================================================================================================
# SENTENCE:
# Ideal candidates will have 3+ years of experience in Core Java Development in an Enterprise level company.
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Core Java Development]
#
# Core Java Development --> 3+ years
# ========================================================================================================================
# SENTENCE:
#  Heartland was founded in 1997 and is the 5th largest credit, debit, payroll and related processing service provider in the United States with over 3000 employees in operations, sales, IT, marketing and administration.
#
# OUTPUT:
# date_list: []
# tem_list: [Heartland, 5th, the United States, 3000]
#
# ========================================================================================================================
# SENTENCE:
#  Our client is looking for a Java Developer for a 6 month project in Rancho Cordova, CA.
#
# OUTPUT:
# date_list: []
# tem_list: [Rancho Cordova, CA]
#
# ========================================================================================================================
# SENTENCE:
# • 3 years experience with Java/J2EE Development  • 2 years experience with application servers –
#
# OUTPUT:
# date_list: [3 years, 2 years]
# tem_list: [Java/J2EE Development]
#
# Java/J2EE Development --> 3 years
# Java/J2EE Development --> 2 years
# ========================================================================================================================
# SENTENCE:
# Glassfish preferred  • 1 year experience in Web-Services Development  • 1 year experience with EJB, JMS, XML, JDBC  • Experience with version and change control software  • Experience with object-oriented design and analysis  DESIRED SKILLS  • CMMI
#
# OUTPUT:
# date_list: [1 year, 1 year]
# tem_list: [Glassfish, Web-Services Development, EJB, JMS, XML, JDBC, CMMI]
#
# Web-Services Development --> 1 year
# EJB --> 1 year
# JMS --> 1 year
# XML --> 1 year
# JDBC --> 1 year
# EJB --> 1 year
# JMS --> 1 year
# XML --> 1 year
# JDBC --> 1 year
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# These energetic team players must be detail-oriented, exhibit good problem solving skills, and enjoy working in a fast-paced environment.?Technical Skill Requirements: 3 or more years of experience in J2EE Environment.?
#
# OUTPUT:
# date_list: [3 or more years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# Direct Hire     Client is in need of Java developer that has experience utilizing Agile methodology (2 week sprints).
#
# OUTPUT:
# date_list: []
# tem_list: [Java]
#
# ========================================================================================================================
# SENTENCE:
# They really want people with 3-5 years of experience.
#
# OUTPUT:
# date_list: [3-5 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
#  Our client is looking for a Java Developer for a 6 month project in Rancho Cordova, CA.
#
# OUTPUT:
# date_list: []
# tem_list: [Rancho Cordova, CA]
#
# ========================================================================================================================
# SENTENCE:
# Contract Duration:  6+ months with possible ongoing extensions
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# 3+ Years of Data Loading experience in a Distributed Data Base environment      3+ Years of Data scalability and multi-tenant data architectures
#
# OUTPUT:
# date_list: []
# tem_list: [Data Loading, Distributed Data Base]
#
# ========================================================================================================================
# SENTENCE:
# 3+ Years of Data architecture and implementation using local or cloud-based storage and NoSQL data stores      3+ Years of Performance and optimization in a large distributed system environment
#
# OUTPUT:
# date_list: []
# tem_list: [Data]
#
# ========================================================================================================================
# SENTENCE:
# These positions are all six month contract to hire positions.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# The ideal candidates will also have experience with or exposure to the following based on their years of experience: - Spring - Hibernate - MVC -
#
# OUTPUT:
# date_list: [their years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Job Title                        : 4728 Java Developer Duration                        : 4 months contract
#
# OUTPUT:
# date_list: []
# tem_list: [Job Title]
#
# ========================================================================================================================
# SENTENCE:
# Pluses: Experience with Spring, queue technologies and XML.
#
# OUTPUT:
# date_list: []
# tem_list: [XML]
#
# ========================================================================================================================
# SENTENCE:
# - 4+ years experience with J2EE technologies, software development life cycle and development tools, or other directly related experience.
#
# OUTPUT:
# date_list: [4+ years]
# tem_list: [J2EE technologies]
#
# ========================================================================================================================
# SENTENCE:
# Requirements: -4 year degree (Computer Science, Information Systems or relational functional field)
#
# OUTPUT:
# date_list: [year]
# tem_list: [(Computer Science, Information Systems]
#
# (Computer Science, Information Systems --> year
# ========================================================================================================================
# SENTENCE:
# Contract     TEKsystems has partnered with a local government integrator to support their need for a Java developer with 2-3 years of experience working in a J2EE environment.
#
# OUTPUT:
# date_list: [2-3 years]
# tem_list: [Java, J2EE]
#
# J2EE --> 2-3 years
# ========================================================================================================================
# SENTENCE:
# Job Specifications: - A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications,
#
# OUTPUT:
# date_list: [at least 6 years]
# tem_list: [Java]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# 7 years of experience can be substituted for a degree                    Join TEKsystems® and get your career on the fast track.
#
# OUTPUT:
# date_list: [7 years]
# tem_list: [Join TEKsystems]
#
# ========================================================================================================================
# SENTENCE:
# We know it''s more than just your day-to-day responsibilities that can make or break a job.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# The right individual will have 3+ years of experience in pure Java Development, J2EE, and Javascript.
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Java Development, J2EE, Javascript]
#
# Java Development --> 3+ years
# J2EE --> 3+ years
# Javascript --> 3+ years
# ========================================================================================================================
# SENTENCE:
# 2+ years experience with core Java technologies and concepts  1+ years of experience with SQL and relational database concepts  BS in Computer Science or related field or equivalent experience
#
# OUTPUT:
# date_list: [1+ years]
# tem_list: [Java, SQL, BS]
#
# SQL --> 1+ years
# BS --> 1+ years
# ========================================================================================================================
# SENTENCE:
# Amazing company:  Annual compensation reviews, generous bonuses, and active “Green Team” and
#
# OUTPUT:
# date_list: []
# tem_list: [Green Team]
#
# ========================================================================================================================
# SENTENCE:
#  MDI Group is a premier IT workforce solutions provider with more than 20 years of expertise in finding “best fit”
#
# OUTPUT:
# date_list: [more than 20 years]
# tem_list: [MDI Group]
#
# ========================================================================================================================
# SENTENCE:
# Modis is currently searching for a Java developers with greater than 2 years of experience to be a part of one of the most exciting teams in the world.
#
# OUTPUT:
# date_list: [2 years]
# tem_list: [Modis, Java, one]
#
# ========================================================================================================================
# SENTENCE:
# A minimum of 2 years IT experience is required.
#
# OUTPUT:
# date_list: [2 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# We have won the Columbus Business First “Fast 50" award 4 times in the last 5 years because of our strong growth which translates into more and better opportunities for our consulting staff members.
#
# OUTPUT:
# date_list: [the last 5 years]
# tem_list: [the Columbus Business First, Fast 50, 4]
#
# ========================================================================================================================
# SENTENCE:
# Ideal candidates will have 3+ years of experience in Core Java Development in an Enterprise level company.
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Core Java Development]
#
# Core Java Development --> 3+ years
# ========================================================================================================================
# SENTENCE:
#  Randstad Technologies is looking for a Java Developer for a 6 months contract to hire position in the Tampa Bay Area.
#
# OUTPUT:
# date_list: []
# tem_list: [Randstad Technologies, the Tampa Bay Area]
#
# ========================================================================================================================
# SENTENCE:
# 5 years of experience using Unix and Linux.
#
# OUTPUT:
# date_list: [5 years]
# tem_list: [Linux]
#
# Linux --> 5 years
# ========================================================================================================================
# SENTENCE:
# Modis is currently searching for a Java developers with greater than 2 years of experience to be a part of one of the most exciting teams in the world.
#
# OUTPUT:
# date_list: [2 years]
# tem_list: [Modis, Java, one]
#
# ========================================================================================================================
# SENTENCE:
# A minimum of 2 years IT experience is required.
#
# OUTPUT:
# date_list: [2 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Contract     TEKsystems has partnered with a local government integrator to support their need for a Java developer with 2-3 years of experience working in a J2EE environment.
#
# OUTPUT:
# date_list: [2-3 years]
# tem_list: [Java, J2EE]
#
# J2EE --> 2-3 years
# ========================================================================================================================
# SENTENCE:
# Java Developer  Bellevue, WA   Duration:   1 Year (Contract to hire)   Job Description:
#
# OUTPUT:
# date_list: []
# tem_list: [Java Developer, Bellevue, WA, Duration]
#
# ========================================================================================================================
# SENTENCE:
# We are looking for Java Developer for our Direct Client in Bristol, CT for 12+ Months contract position.
#
# OUTPUT:
# date_list: []
# tem_list: [Bristol, CT]
#
# ========================================================================================================================
# SENTENCE:
# Bristol, CT Duration: 10 Months +   Description:
#
# OUTPUT:
# date_list: []
# tem_list: [Bristol, CT]
#
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# 6 years of experience in related technical discipline.
#
# OUTPUT:
# date_list: [6 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# •The successful candidate must possess a good understanding of enterprise architecture, web technologies, and have 3+ years of hands-on Java / J2EE development experience.
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Java / J2EE]
#
# Java / J2EE --> 3+ years
# ========================================================================================================================
# SENTENCE:
# This company has been named one of Fortune Magazine’s top 100 companies to work for over ten years.
#
# OUTPUT:
# date_list: [ten years]
# tem_list: [one, Fortune Magazine, 100]
#
# ========================================================================================================================
# SENTENCE:
# If working in an environment where you have the freedom to voice your opinions and collaborate among other top-notch technical folks, apply today!
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# 3-5 years academic or work experience in software development              Experience working with Agile development methodologies (Scrum), preferred              Design, develop and maintain applications developed in various program languages and technologies, including but not limited to:         o Java (Swing GUI and Web)
#
# OUTPUT:
# date_list: [3-5 years]
# tem_list: [Java, Web]
#
# ========================================================================================================================
# SENTENCE:
# o Spring, Spring MVC
#
# OUTPUT:
# date_list: []
# tem_list: [MVC]
#
# ========================================================================================================================
# SENTENCE:
# ...
# tem_list: [TX]
#
# ========================================================================================================================
# SENTENCE:
# Our client in Rockville, MD is looking for highly skilled and motivated Java developers with 0-5 years of experience with a degree in Computer Science to join their team.
#
# OUTPUT:
# date_list: [0-5 years]
# tem_list: [Rockville, MD, Java, Computer Science]
#
# Computer Science --> 0-5 years
# ========================================================================================================================
# SENTENCE:
# The development teams are very small with a Matrix environment utilizing a very Agile methodology with 2-3 week sprint cycles.
#
# OUTPUT:
# date_list: []
# tem_list: [Matrix]
#
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# Technical - Bachelors/Master of Science in Computer Science or related field - Experience in Java & SQL  - Experience in Agile environment preferred - Knowledgeable in MS Windows  - Ability to accurately scope, plan and estimate level of effort for large-scale initiatives with appropriate balance of risk and effort - Proficient in software life cycle methodologies - Demonstrated strength with complex problem decomposition - Ability to work well with a team of highly talented software professionals in a rapid development environment - Proven ability in designing and building very large database systems, highly redundant systems, and distributed network solutions - Strong programming skills in Java or J2EE technologies Salary:60-80k Required Skills for Entry Level
#
# OUTPUT:
# date_list: []
# tem_list: [Technical - Bachelors, Java & SQL, Java, J2EE technologies, Skills for Entry]
#
# ========================================================================================================================
# SENTENCE:
# We know it''s more than just your day-to-day responsibilities that can make or break a job.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Must have 3+ years
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Java application development experience  Must have 3+ years
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Java]
#
# ========================================================================================================================
# SENTENCE:
# Must have 3+ years
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Must have 3+ years
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Four years of Java/J2EE experience.
#
# OUTPUT:
# date_list: [Four years]
# tem_list: [Java/J2EE]
#
# Java/J2EE --> Four years
# ========================================================================================================================
# SENTENCE:
# Contract     Teksystems is looking for a front end Java Developer for a 10 -12 month contract opportunity for a client in the Orlando, Florida area.
#
# OUTPUT:
# date_list: []
# tem_list: [Orlando, Florida]
#
# ========================================================================================================================
# SENTENCE:
# We are looking for Java Developer with at least five years of Java Development experience.
#
# OUTPUT:
# date_list: [at least five years]
# tem_list: [Java Development]
#
# Java Development --> at least five years
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# Required Skills• BS in Computer Science preferred (or similar degree) with 3+ years of experience; • Ability to obtain and maintain a secret clearance; • Strong familiarity with C#/C/C++ programming language;   •
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Skills• BS, Computer Science, C#/C/C++]
#
# ========================================================================================================================
# SENTENCE:
# -Four years of UI development experience (HTML, Javascript, and CSS).
#
# OUTPUT:
# date_list: [years]
# tem_list: [Javascript]
#
# Javascript --> years
# ========================================================================================================================
# SENTENCE:
# -Three years of Spring Framework experience.
#
# OUTPUT:
# date_list: [years]
# tem_list: [Spring Framework]
#
# Spring Framework --> years
# ========================================================================================================================
# SENTENCE:
# -Three years of experience developing EJBs.
#
# OUTPUT:
# date_list: [years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# -Three years of experience developing JSPs.
#
# OUTPUT:
# date_list: [years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# (i.e. Struts, Spring MVC, etc.).
#
# OUTPUT:
# date_list: []
# tem_list: [Struts]
#
# ========================================================================================================================
# SENTENCE:
# years experience with the Rational Application Developer (RAD) or Eclipse tool.
#
# OUTPUT:
# date_list: [years]
# tem_list: [the Rational Application Developer, Eclipse]
#
# the Rational Application Developer --> years
# Eclipse --> years
# ========================================================================================================================
# SENTENCE:
# -Four years of experience working with relational databases (MS-SQL Server, Oracle, etc) and concepts.
#
# OUTPUT:
# date_list: [years]
# tem_list: [Oracle]
#
# Oracle --> years
# ========================================================================================================================
# SENTENCE:
# -Three years of experience applying the Unified Modeling Language (UML) standard using a modeling or diagram tool (i.e. Rational Rose, Visio, etc).
#
# OUTPUT:
# date_list: [years]
# tem_list: [the Unified Modeling Language (UML, Rational Rose, Visio]
#
# the Unified Modeling Language (UML --> years
# Rational Rose --> years
# Visio --> years
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# A bachelors degree in Computer Science or Engineering and at least 6 years of Java experience working with server side applications, 7 years of experience can be substituted for a degree Candidates must be clearable US Citizens or hold at least an interim DOD security clearance
#
# OUTPUT:
# date_list: [at least 6 years, 7 years]
# tem_list: [Java, US, DOD]
#
# Java --> at least 6 years
# ========================================================================================================================
# SENTENCE:
# 5 years or more experience.
#
# OUTPUT:
# date_list: [5 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Daily tasks – (this is not an exact list, but a general list)
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# • Bachelor's Degree in Computer Science required, Masters a plus  • 3+ years of Java server development  • Knowledge/experience in developing Web Services using Service-Oriented concepts, standards and implementations  • Knowledge/experience in developing manageable, high-performance, and massively scalable application architectures distributed across multiple, heterogeneous platforms (e.g., hardware, operating system, server software, browsers, etc.)
#
# OUTPUT:
# date_list: [3+ years]
# tem_list: [Bachelor, Java, Web Services, Service-Oriented]
#
# ========================================================================================================================
# SENTENCE:
# This will be a 2 month contract.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# This is also a true development position where you are not boggled down with the stress/pressures of numerous daily meeting                  Join TEKsystems® and get your career on the fast track.
#
# OUTPUT:
# date_list: []
# tem_list: [Join TEKsystems]
#
# ========================================================================================================================
# SENTENCE:
# As a contractor, the project will last 1-1.5 years.
#
# OUTPUT:
# date_list: []
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Over the past year, we have more than doubled our technical staff and we are still growing!
#
# OUTPUT:
# date_list: [the past year]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# The VBMS program is a multi-year effort to transition the current paper-based Veterans claims process to a paperless solution which will reduce the average time for veteran benefits claim processing, reduce the number of claims in the VBA backlog, and automate claims tracking.
#
# OUTPUT:
# date_list: [multi-year]
# tem_list: [VBMS, Veterans, VBA]
#
# ========================================================================================================================
# SENTENCE:
# Contract     TEKsystems has partnered with a local government integrator to support their need for a Java developer with 2-3 years of experience working in a J2EE environment.
#
# OUTPUT:
# date_list: [2-3 years]
# tem_list: [Java, J2EE]
#
# J2EE --> 2-3 years
# ========================================================================================================================
# SENTENCE:
# Job Title                        : 4728 Java Developer Duration                        : 4 months contract
#
# OUTPUT:
# date_list: []
# tem_list: [Job Title]
#
# ========================================================================================================================
# SENTENCE:
# Pluses: Experience with Spring, queue technologies and XML.
#
# OUTPUT:
# date_list: []
# tem_list: [XML]
#
# ========================================================================================================================
# SENTENCE:
# Genesis10 is actively seeking a Java Developer 8 month contract role with a retail company located in Minneapolis, MN.
#
# OUTPUT:
# date_list: []
# tem_list: [Genesis10, Minneapolis, MN]
#
# ========================================================================================================================
# SENTENCE:
# accurate status of projects aligned with the methodology being used (SCRUM/Iterative/ Waterfall)            Carry a Tier-2 support pager on a 6  8 week rotation           Support, maintenance, and development of JAVA web based and stand-alone applications    QUALIFICATIONS:
#
# OUTPUT:
# date_list: []
# tem_list: [6, JAVA, QUALIFICATIONS]
#
# ========================================================================================================================
# SENTENCE:
# EDUCATION and/or EXPERIENCE:             5-6 years work experience in a J2EE development/maintenance environment.
#
# OUTPUT:
# date_list: [5-6 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Candidates must be a team player with a minimum of 3 years IT experience.
#
# OUTPUT:
# date_list: [3 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# 3 years of software development3)
#
# OUTPUT:
# date_list: [3 years]
# tem_list: []
#
# ========================================================================================================================
# SENTENCE:
# Contract to Hire, H-1 or Subcontractors will NOT be considered)   4 -6  years professional experience required.
#
# OUTPUT:
# date_list: []
# tem_list: [Hire]
#
# ========================================================================================================================
# SENTENCE:
# Top skills: Core Java, Unit Testing, EJB  Job Responsibilities: --Develop cutting edge mobile applications on the Android platform  Requirements: --BS in computer science or equivalent --Strong Core Java Skills, at least 2 year development experience --Strong Unit Testing Skills, JUnit development experience --Strong experience with EJB's (Message Beans, JMS, Entity Beans)  --Object
#
# OUTPUT:
# date_list: [at least 2 year]
# tem_list: [EJB, Android, Core Java Skills, EJB, JMS, Entity Beans]
#
# ========================================================================================================================
# SENTENCE:
# This is a 6 month contract to hire position in Orangeburg, NY
#
# OUTPUT:
# date_list: []
# tem_list: [Orangeburg, NY]
#
# ========================================================================================================================
# SENTENCE:
# Contract     Teksystems is looking for a front end Java Developer for a 10 -12 month contract opportunity for a client in the Orlando, Florida area.
#
# OUTPUT:
# date_list: []
# tem_list: [Orlando, Florida]
#
# ========================================================================================================================
# SENTENCE:
# We are looking for Java Developer with at least five years of Java Development experience.
#
# OUTPUT:
# date_list: [at least five years]
# tem_list: [Java Development]
#
# Java Development --> at least five years
