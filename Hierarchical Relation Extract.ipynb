# %%
import pandas as pd
from collections import Counter
import spacy,re,json
from spacy.gold import GoldParse
from spacy.scorer import Scorer
from spacy import displacy  

from sklearn.metrics import classification_report
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score

import re
from pprint import pprint
import os
import warnings
warnings.filterwarnings('ignore')

from __future__ import unicode_literals, print_function
import plac
import random
from pathlib import Path
import spacy
from spacy.util import minibatch, compounding

# %% [markdown]
# # ============================================================
# ## 基于 Spacy 的 NER 模型

# %%
PATH ='data/file_ner.json1'

annotated_data = []
lines=[]
with open(PATH, 'r',encoding = 'utf-8 sig') as f:
    lines = f.readlines()

for line in lines:
    data = json.loads(line)
    text = data['text']
    entities = []
    for label in data['labels']:
        entities.append(label)
    annotated_data.append((text, {"entities": data['labels']}))

# %%
training_data=  annotated_data[0:200]
test_data = annotated_data[200:220]

# %%
print(len(training_data), len(test_data))
# Out:
# 200 20

# %%
training_data[0]
# Out:
# ('"Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company\'s growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)  ADDITIONAL INFORMATION  Technical Skills  https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN   • Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player"',
#  {'entities': [[994, 995, 'Skills'],
#    [1016, 1024, 'Skills'],
#    [1045, 1064, 'Skills'],
#    [1085, 1111, 'Skills'],
#    [1132, 1136, 'Skills'],
#    [1321, 1322, 'Skills'],
#    [1324, 1327, 'Skills'],
#    [1329, 1333, 'Skills'],
#    [1335, 1353, 'Skills'],
#    [1356, 1374, 'Skills'],
#    [1376, 1393, 'Skills'],
#    [1396, 1422, 'Skills'],
#    [1425, 1442, 'Skills'],
#    [1473, 1478, 'Skills'],
#    [1480, 1487, 'Skills'],
#    [1489, 1492, 'Skills'],
#    [1612, 1623, 'Skills']]})

# %%
def main(model=None, output_dir=None, n_iter=100):
    """Load the model, set up the pipeline and train the entity recognizer."""
    if model is not None:
        nlp = spacy.load(model)  # load existing spaCy model
        print("Loaded model '%s'" % model)
    else:
        nlp = spacy.blank("en")  # create blank Language class
        print("Created blank 'en' model")

    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    if "ner" not in nlp.pipe_names:
        ner = nlp.create_pipe("ner")
        nlp.add_pipe(ner, last=True)
    # otherwise, get it so we can add labels
    else:
        ner = nlp.get_pipe("ner")

    # add labels
    for _, annotations in training_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])

    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
    with nlp.disable_pipes(*other_pipes):  # only train NER
        # reset and initialize the weights randomly – but only if we're
        # training a new model
        if model is None:
            nlp.begin_training()
        for itn in range(n_iter):
            random.shuffle(training_data)
            losses = {}
            # batch up the examples using spaCy's minibatch
            batches = minibatch(training_data, size=compounding(4.0, 32.0, 1.001))
            for batch in batches:
                texts, annotations = zip(*batch)
                nlp.update(
                    texts,  # batch of texts
                    annotations,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
            print("Losses", losses)

    # test the trained model
    for text, _ in training_data:
        doc = nlp(text)
#         print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#         print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

    # save model to output directory
    if output_dir is not None:
        output_dir = Path(output_dir)
        if not output_dir.exists():
            output_dir.mkdir()
        nlp.to_disk(output_dir)
        print("Saved model to", output_dir)

        # test the saved model
        print("Loading from", output_dir)
        nlp2 = spacy.load(output_dir)
        for text, _ in training_data:
            doc = nlp2(text)
#             print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
#             print("Tokens", [(t.text, t.ent_type_, t.ent_iob) for t in doc])

# trained this model with 100 iterations in google colab using GPU runtime with loss: Losses {'ner': 465.24571515528373} 
main(output_dir='ner_model/')
# Out:
# Created blank 'en' model
# Losses {'ner': 16768.48688307873}
# Losses {'ner': 2761.7945596546524}
# Losses {'ner': 2586.147553201028}
# Losses {'ner': 2763.2860978442395}
# Losses {'ner': 2439.4767436901693}
# Losses {'ner': 2687.634682729234}
# Losses {'ner': 2355.694131632732}
# Losses {'ner': 2189.2004296167097}
# Losses {'ner': 2085.9152812762695}
# Losses {'ner': 1990.533282201601}
# Losses {'ner': 1912.0705477855574}
# Losses {'ner': 1851.9641642381605}
# Losses {'ner': 1800.518135927293}
# Losses {'ner': 1707.7367110706346}
# Losses {'ner': 1723.845531718316}
# Losses {'ner': 1701.1866226226925}
# Losses {'ner': 1561.5885531001795}
# Losses {'ner': 1501.297711165509}
# Losses {'ner': 1604.1706923918568}
# Losses {'ner': 1385.7271474510703}
# Losses {'ner': 1496.3298702131035}
# Losses {'ner': 1346.2760019554257}
# Losses {'ner': 1429.2420476255181}
# Losses {'ner': 1287.5133737691833}
# Losses {'ner': 1438.9120273613385}
# Losses {'ner': 1145.246637270898}
# Losses {'ner': 1284.8927977882884}
# Losses {'ner': 1152.3211780370452}
# Losses {'ner': 1231.2644683263343}
# Losses {'ner': 1186.0434697899645}
# Losses {'ner': 1122.3317062744018}
# Losses {'ner': 1080.5432083962419}
# Losses {'ner': 1100.5992578152702}
# Losses {'ner': 1117.1921802717418}
# Losses {'ner': 1017.1517374167818}
# Losses {'ner': 1073.7221002616884}
# Losses {'ner': 986.2070826104613}
# Losses {'ner': 1158.7660201310384}
# Losses {'ner': 1135.4405201762238}
# Losses {'ner': 937.894491469815}
# Losses {'ner': 1077.229263141422}
# Losses {'ner': 915.0246695468783}
# Losses {'ner': 875.7790541777774}
# Losses {'ner': 970.8855705151078}
# Losses {'ner': 1054.4116086675601}
# Losses {'ner': 1002.8738830023987}
# Losses {'ner': 870.7439951888412}
# Losses {'ner': 882.9143580349678}
# Losses {'ner': 916.4106285938939}
# Losses {'ner': 895.8531089689642}
# Losses {'ner': 875.8555063967443}
# Losses {'ner': 705.2041403744907}
# Losses {'ner': 864.1945957256061}
# Losses {'ner': 840.6336602158045}
# Losses {'ner': 788.231916222551}
# Losses {'ner': 791.8664888586561}
# Losses {'ner': 769.3020972179177}
# Losses {'ner': 765.7286437057728}
# Losses {'ner': 685.0203397891277}
# Losses {'ner': 690.1866098450112}
# Losses {'ner': 724.9301863193272}
# Losses {'ner': 721.3601740629673}
# Losses {'ner': 775.7054934090759}
# Losses {'ner': 663.4413194140832}
# Losses {'ner': 663.1866380751044}
# Losses {'ner': 666.256771006334}
# Losses {'ner': 723.5823858874653}
# Losses {'ner': 694.9495270535199}
# Losses {'ner': 655.2828704920413}
# Losses {'ner': 688.110040200505}
# Losses {'ner': 650.5381446906247}
# Losses {'ner': 585.9811260668242}
# Losses {'ner': 626.2515915890917}
# Losses {'ner': 669.5110457434583}
# Losses {'ner': 584.1927261759149}
# Losses {'ner': 661.1684829602799}
# Losses {'ner': 606.5799019076904}
# Losses {'ner': 634.1589370376861}
# Losses {'ner': 586.713568365702}
# Losses {'ner': 648.0718946314877}
# Losses {'ner': 617.7031942626638}
# Losses {'ner': 630.9469675388966}
# Losses {'ner': 486.40478457297274}
# Losses {'ner': 539.4871280979542}
# Losses {'ner': 541.7185135361171}
# Losses {'ner': 480.9462733866497}
# Losses {'ner': 481.59553283097796}
# Losses {'ner': 500.46702149925096}
# Losses {'ner': 551.3150251673919}
# Losses {'ner': 519.4057642796206}
# Losses {'ner': 407.44613304804204}
# Losses {'ner': 425.6206119342152}
# Losses {'ner': 473.6191308882646}
# Losses {'ner': 510.1232347424807}
# Losses {'ner': 466.91988115237365}
# Losses {'ner': 454.665722710303}
# Losses {'ner': 454.78673481229015}
# Losses {'ner': 462.0522672140284}
# Losses {'ner': 481.16972209964155}
# Losses {'ner': 496.5335785365188}
# Saved model to ner_model
# Loading from ner_model

# %% [markdown]
# # ==========================================================
# ## 导入 NER 模型，识别 JD 中的所有技能类关键词

# %%
ner_model = spacy.load('ner_model/')

# %%
skill_set = {}
link_set = {}

# %%
ind = 0

for root,dirs,files in os.walk(r"E:\dataset\dataset"):
    for file in files:
        ind += 1
        
        try:
            #获取文件路径
            my_file = open( os.path.join(root,file),encoding = 'utf-8' )
            my_string = my_file.readlines()

            for string in my_string[1:]:
                doc = ner_model( string )

                temp_list = []
                for chunk in doc.ents:
                    temp_list.append( chunk.text )
                    
                temp_set = set( temp_list )
                
                for tem in list(temp_set):
                    if tem not in skill_set.keys():
                        print( tem )
                        
                    if skill_set.get( tem, 0 ) == 0:
                        skill_set[tem] = 1
                    else:
                        skill_set[tem] += 1
                        
                for t1 in list(temp_set):
                    for t2 in list(temp_set):
                        if t1.text != t2.text:
                            if link_set.get( t1+'|'+t2, 0 ) == 0:
                                link_set[t1+'|'+t2] = 1
                            else:
                                link_set[t1+'|'+t2] += 1
                            

            my_file.close()
        
            if ind % 100 == 0:
                print( '------------------------------------------------------------------------',ind )
                
#             if ind > 2000:
#                 break
                
        except:
            pass
# Out:
# Logistic Regression
# Python libraries
# Machine Learning
# Python
# BlackRock
# R
# Java
# Map/Reduce
# C
# C++
# SQL
# artificial neural networks
# Random Forest
# Spark
# SAS
# MATLAB
# Neural Networks
# Operations Research
# software prototyping
# Deep Learning
# via SQL
# C ##
# C#
# Javascript
# Analytics
# Consumer experience
# Hadoop
# TensorFlow
# TV planning
# To
# Data Analytics
# Deep Neural Networks
# Google Analytics
# Google Big Query (a
# Create cutting
# ·
# machine learning
# MLlib
# Python R
# Data Engineers
# Google Platform
# containerisation (Kubernetes
# Kubeflow
# Cloud Enablement
# Infrastructure Support
# ; Testing
# Docker
# Data Engineering
# Business Intelligence
# Informatica
# SAP HANA
# Node.JS
# Excel
# e.g. Python
# data mining/predictive analytics
# as Redshift
# S3
# Athena
# Kinesis
# SPSS
# Tensorflow
# Development
# Engineering Support
# Matlab
# Powerpoint
# Microsoft Office
# Visio
# predictive modeling
# problem-solving
# NoSQL
# regression analysis
# visual (presentations
# non-parametric
# national origin
# Oracle
# create insightful
# XML
# MS Windows
# Visualization
# Oracle/SQL
# GitHub
# - SQL
# MA building
# ETL
# Advanced SQL
# PHP
# Problem solving
# Data Platform
# Artificial Intelligence
# Data Visualization
# Data/Advanced Analytics
# BigQuery
# Kubernetes
# PyTorch
# Data Mining
# Google Data Studio
# Torch
# Caffe
# Cloud Computing
# If you
# MS Reporting
# Economics
# Tableau
# Visual Analytics
# Elasticsearch
# Machine learning
# AI
# SQL If you
# Data Scientist
# Python/R
# shell scripting
# advanced analytics
# ECS
# deep learning
# Data Analysts
# JavaScript
# SPARK
# GCP
# AWS
# Azure If you
# predictive analytics
# Sequence Modeling
# Learning
# Microsoft T-SQL
# NLP
# Optimization AI
# Power BI
# Redshift
# Map Reduce
# GLM/Regression
# Databricks
# GGlpot
# Nompy
# SQL experience
# Google Big Query a
# relational databases
# SAS/R
# artificial intelligence
# Software Development
# software engineering
# SQL advanced SQL
# Machine -Learning
# A/B Testing
# Equity
# Microsoft SQL
# SQL Server
# Finance
# problem solving
# DevOps/AWS
# Chef
# Ansible
# Jenkins
# SAP Predictive Analytics
# Engineering
# Marketing
# Linux
# Julia
# e.g.
# statistical software (e.g.
# PowerPoint
# Microsoft Access
# Python and/or R
# GLM
# Advanced SAS
# R statistical
# SQL If you are a Data Scientist
# SaaS
# statistical analysis
# AWS - Redshift
# Jupyter Notebooks
# Pear Ventures
# Data Science
# Looker If you are a Data Scientist
# Data Analysis
# Recommendation Systems
# Direct Analytics
# Yield Management
# Network Planning
# query
# Data analytics
# Microsoft T-SQL SSIS
# ------------------------------------------------------------------------ 200
# MS Office
# Business
# MS SQL
# SSIS
# stacks
# Git
# advanced SQL
# Statistical Modeling
# Data enrichment
# Data quality evaluations
# R and/or Python
# Recurrent Neural Networks
# Convolutional Neural Networks
# SQL/relational databases (e.g.
# OF A RESUME IS NOT A GUARANTEE
# Algorithmic Development
# SQL/RDBMs
# Big Data
# Data Modeling
# MySQL
# AWS Redshift
# Snowflake
# Vertica
# Early Equity
# PostgreSQL
# Predictive Modeling
# Inventory Management
# Industrial Engineering
# Pricing/Price
# MS SQL Server
# MS Access
# Azure Data Lake
# Crimson Hexagon
# DigitalOcean
# regression,
# DivIHN
# Palo Alto
# Google Cloud
# Splunk
# clustering
# ensembling
# Predictive Analytics
# Word
# regression
# ------------------------------------------------------------------------ 300
# Statistics
# Google Cloud Platform
# statistical learning
# information visualization
# Deep Reinforcement
# cloud computing
# data visualization
# Tableau If you
# Pandas
# GCP/
# Google / AWS
# Go
# XGBoost
# Postgresql
# MYSQL
# Develop analytics
# data engineering
# AI and
# scikit-learn
# Business Analytics
# Data Lake
# Spark / R
# EC2
# Spark / Redshift
# Fargo Audit
# Structured Query
# Predictive modeling
# Hypothesis testing
# Customer Analytics/
# Functional Experience
# Teradata
# MIS
# advanced analytic effectiveness reporting
# LaTeX,
# SQLite
# data reporting
# e.g. MySQL
# Map reduce
# Deep learning
# Data analysis
# Oracle PL/SQL
# machine-learning
# Django
# Experienced
# Data Visualization If you are a Data Scientist
# QA experts
# Base SAS
# SAS QA
# text analytics
# AI
#
# Predictive model building
# Databricks / Apache Spark
# J2EE
# as R
# Apache Kafka
# Apache Storm
# T-SQL
# Adobe Analytics
# Cognitive Services
# PL-SQL
# OrionDB
# TOAD
# Microsoft SQL Server
# Oracle SQL
# EBS
# Visual Basic
# Application Testing
# BI Dashboard
# Information Map Studio
# OLAP Cube Studio
# Data Integration Studio
# Azure Cognitive Services
# Microsoft Word
# Apache Hadoop
# hypothesis testing
# ------------------------------------------------------------------------ 500
# MapReduce
# Sales
# Market Research
# Network
# Matter Experts
# Businesses Intelligence
# 5
# Apache Pig
# Apache Spark
# Perl
# Sales & Marketing
# SAP
# Github
# Managerial experience
# IBM ·
# /experience
# creative problem solving
# AWS/C2S
# data access
# (e.g.
# any scripting
# customer retention
# advanced computing
# Advanced degree
# Microsoft Visual Studio
# PERL
# Subject Matter Experts
# D3
# MS Excel
# statistical
# statistical modeling
# marital status
# LaTeX
# HTML
# SAS/Access
# Google analytics
# Azure
# models
# Scoop Analytics
# TX - R
# IT - Analytics
# Predictive Analysis
# the Hadoop
# AWS If you are a Data Scientist
# NICE TO
# CSS)Power BI
# D/V
# Block 18
# ------------------------------------------------------------------------ 700
# social network analysis
# Windows Server
# R-00007556
# data analytics
# Kafka
# research
# predictive Modeling
# HDFS
# MongoDB
# scripting
# Database Design
# RDBMS
# Business Analysis
# Octopus Deploy
# Azure Data Lake Analytics
# CI/CD
# job performance
# Aptible
# Postgres
# MXNET
#
# etc.﻿
# Azure XML
# Spark ML
# Alpine
# Research
# Data Architect
# Digital Analytics
# Loyalty Programs
# Customer Analytics
# Mongo
# Neo4j
# DB2
# visualization
# Revolution R
# programming SQL/R
# SSH
# Google or Redshift
# MS Word
# Microsoft Azure analytics
# Data Pipeline / Kafka
# Azure Analytics
# Ruby / DynamoDB
# RDS/ Redshift
# Data Lake Analytics
# Azure / Cloud /
# DB structures (SQL
# & Hadoop
# Strong SQL
# Strategic analytics
# Regression,
# /Lifecycle
# GovCLoud
# MSSQL Experience
# Data Center
# network analysis
# Microsoft office
# Github Experience
# prototyping
# engineering
# MatLab
# Tele sales & Retention
# Integration testing
# Unit testing
# Mathematics
# ------------------------------------------------------------------------ 900
# consumer trends
# CPG)
# our technology
# NlLJMv1Y7Hk
# Redis
# Regression
# andor
# Analysis
# Python andor R
# mainframe computing
# R and/or SPSS
# advanced SAS
# graph
# JavaScript and/or
# PL/SQL
# Information Technology
# Personnel
# SQL
#
# ArcGIS
# some visualization tool
# Version Control System
# Petrel
# Statistical analysis
# Datalake
# Support
# Workbench
# Datalake analytics
# EFS
# wrangling
# Power Point
# Oracle Consulting
# ID (
# machine leaning
# biomedical research
# R & MATLAB
# - Designing
# Oracle BI
# d Hadoop
# Jupyter
# R Analytics
# statistical concepts
# Azure ML
# 3
# Models
# Java/Java script
# cloud computing services
# GCP Cloud
# graph networks
# Python / R
# Neo4j / Hadoop
# Data Integration
# JCR
# Reports
# Information Visualization
# Advanced Data Analytics
# R Studio
# Microsoft Office applications
# deepl learning
# Team player
# Design SQL
# OPPORTUNITY
# Sagemaker
# PostgreSql
# MySql
# shot learning
# jQuery,
# subsystems
# Modeling & Simulation (M&S
# Air Force
# SAF/AQ
# Gummy Drop
# 1
# including Word
# Oracle database
# campaign execution
# Sales Operations
# EDW
# Experience
# Asset Management
# creative services
# Cisco
# NOSQL
# SAS; R
# logistic)
# non-linear
# MS BI
# ORACLE
# MS Power BI
# IBM
# My Structured
# SQL AWS
# Mode Analytics
# STATA
# customer segmentation
# data querying
# Advanced Analytics
# Database Management
# Statistical modeling
# Collaborative Filtering
# and/or R
# python/R
# targeting systems
# AWS Elastic
# Data visualization
# TX / Cloud Big
# Austin
# Java / Kubernetes
# technology
# IoT
# Time series analysis
# customer experience
# ------------------------------------------------------------------------ 1400
# operations research
# source control
# Hadoop / Map-Reduce
# Optimization
# data analysis
# Data visualization experience
# analytics
# sex
# Java and/or
# ASP.net
# Artificial Intelligence sharing
# CPLEX
# reverse engineering
# Advertising
# Digital and/or
# Fraud
# GCP/AWS
# solving
# as R/R Studio
# ElasticSearch
# Data management
# CSS
# technical analytics
# Azure Analysis
# ------------------------------------------------------------------------ 1500
# optimization
# statistical software
# Management
# Office
# Theano
# PowerShell
# the Assistant
# Modeling
# Torch,
# Bing Ads
# Google AdWords
# RedShift
# Confluence
# JIRA
# DATA SCIENTIST
# RESEARCH DEPARTMENT
# required (Hadoop
# Advanced analytics
# public speaking
# We
# SOAP
# Sales management
# Visualization - R
# Data Analysis - R
# Data Integration - able
# NE
# Chicago IL
# Programming/Development
# Perl and shell scripting
# java
# Matlab; distributed computing
# regression methods
# BARRA; risk
# Query databases
# Sciences
# ------------------------------------------------------------------------ 1700
# GCP and/or
# Azure IOT
# Adobe Advertising Cloud
# Bigquery
# git
# Unix/
# administrative/office
# model building
# nature language
# Access
# SCAN
#
# Tableau R
# and/or NoSQL
# databases
# Optimization Predictive
# product management
# SPSS and/or
# Marketing Analytics
# Operations
# Product Management
# Application Development
# Python(PyPi),Text analysis
# Microsoft Reporting Studio
# ------------------------------------------------------------------------ 1800
# ECommerce
# Random Forests
# Deterministic Forests
# Search Engine Marketing
# Facebook Analytics
# and/or Amazon Marketing
# Data recruitment
# Design Quality
# SASUnix
# Director
# Unix
# NOSQL databases
# MSSQL
# Jira
# DevOps
# PERKS
# Python/PySpark
# reinforcement learning
# Azure Kubernetes
# Azure Databricks
# Text Analytics
# Neon
# SystemML
# Data Intelligence
# Data Governance
# feature transformation
# non-experts
# Python
# Spark and/or
# R SQL Experience
# Problem Solving
# Core Attributes
# Judgment/
# Statistical Analysis
# SQL Experience
# including R
# e.g. Java
# concepts
# Network Management
# EMS)
# Energy Management System
# Distribution Management System
# including Python
# Map-Reduce
# e.g. SQL
# programming (e.g. R
# Ensembling
# Required
# Data Analyts
# create lasting
# as analytics
# ------------------------------------------------------------------------ 2000
# data blending
# SageMaker
# + SQL
# R studio
# graph analytics
# Miner
# Alpine Data Labs
# Keras
# SAS/STAT
# BASE
# Centrality Analysis
# Data Transformation
# IBM SPSS
# consumer analytics
# operations analysis
# Client Analytics
# Inventory Planning
# Product Development
# Technology
# Sales and
# specifically S3
# Database structures (SQL
# &bull
# Business Development
# Digital Marketing
# Google Cloud Platform a plus
# ------------------------------------------------------------------------ 2100
# predictive maintenance
# Model Development
# HR BI
# data mining
# operational research
# medical affairs
# Blueprism
# IT Application Developer
# classical hypothesis testing
# Advanced understanding
# -Experience
# Math
# build predictive analytics
# Java Script
# Feature Engineering
# Home Equity
# Microsoft Azure
# Cognitive Sciences
# SAP Hana
# Spark Sql
# cognitive services
# Cosmo DB
# financial engineering
# Michigan
# Restful API
# JAVA
# Angular
# including Java
# Advanced Excel
# Protégé
# Crucible
# Apache Jena
# Apache Groovy
# Atlassian Confluence
# Bitbucket
# TopBraid
# Apache SVN
# Eclipse RDF4J
# PyCharm
# Software Engineering
# Tableau Eclipse
# Apache Maven
# DevOps; Experience
# teller
# warehouses
# Linux shell scripting
# Information Management
# ECS seeks a
# statistical analysis system
# PDM
# word
# excel
# neural networks
# Master’s
# team
# Governance &
# automation
# QGIS/ArcGIS
# using scripting
# UDFs
# Michigan
#
# Detroit
# and/or analytics
# NODE RED
# Choice Modeling
# Business analytics
# Python and/
# Clickfox
# Great location
# KNIME
# Privacy Notice
# statistical testing
# At P&G
# Operational Research
# PYTHON and/or R
# ------------------------------------------------------------------------ 2400
# Question Answering
# technical field
# DiDi Chuxing
# Base
# recommender systems
# architecture
# Jave
# SAP SLT
# simulation
# RDS e.g.
# (Redshift
# Pattern Recognition
# Web Analytics
# Practical experience
# Python Developer
# MS Azure
# advanced epidemiology
# Network Analysis
# MS-SQL
# unit testing
# Business Process Reengineering
# Ohio (OH
# Livonia
# May 7
# BigData and SQL
# REST API
# advanced predictive analytics
# Spotfire
# Data transformation
# RDS experience
# people analytics
# DynamoDB
# SQS
# Kinsesis
# digital analytics
# cognitive analytics
# TX Job
# Plano
# Bioinformatics
# Systems Development
# Testing
# Spark SQL
# non-SQL
# cluster analysis
# content analysis
# Spark / H2O
# Linux shell script
# MLLib
# Consumer Lifecycle Management
# business analysis
# MXNet
# troubleshooting
# Economics/Econometrics
# Sas
# recommendation systems
# Python JavaScript
# credit research reports
# UCSF
# SQL; Python; R; VBA
# Data Wrangling
# Data Storytelling
# database query languages
# R and/or
# Exempt / Office
# ------------------------------------------------------------------------ 2800
# Warehouse /
# GCP / NumPy / SQL
# Market Access
# MSSQL
# HANA
# Qlik
# unsupervised learning
# software design patterns
# SQL and/or
# REACT JS
# Angular JS
# VUE JS
# feature engineering
# At Fossil
# SQL and/or R required
# ------------------------------------------------------------------------ 3000
# visual neuroscience
# network modeling
# research methods
# statistical data analytics
# advanced Excel
# economics
# We care
# ML
# ETL management
# SQL/
# Apache
# SQL Hadoop
# data modeling
# i.e. R
# Operation Research
# i.e. Java
# Software Dev
# M.S.
# Jun 18
# Rest API
# AI; predictive/prescriptive modeling; personalization and recommendation algorithms; natural language processing and text mining; search recall, precision, ranking, and related problems; large scale forecasting; optimization
# Dataiku
# elastic cloud compute;
# bash scripting
# SQL Experienced
# Oracle Database
# years SQL
# Google BigQuery
# Governance programs
# Data Architecture
# Statistical Programming
# Six Sigma
# advanced analytics experience
# Regression Analysis
# Strong SQL Scripting
# Java/Python/R
# Standard Query Language(SQL
# AWK
# Years Of
# python
# Oracle SQL Developer
# SQL Server Management Studio
# Visual Studio
# XSLT
# Azure engineering
# IBM Chief
# core statistical
# demonstrate
# Unix shell scripting
# quality control
# Data Warehousing
# Technical Services
# Customer Service
# statistical analytics
# multivariate testing
# TX 75023
#
# JOB POSTING
# bound togetherby a
# behavioral analytics
# Global Analytics
# statistical analyses
# Power Query
# Data Management
# Unix Shell Scripting
# statistical research
# conversion Modeling
# ------------------------------------------------------------------------ 3400
# Redis
#
# TX
# R/Python
# Possesses 5
# and predictive analytics
# mathematical data analysis
# Map-reduce
# shell experience
# Computer Science
# Internet Marketing experience
# MxNet
# especially Word
# .NET
# SAS-BI
# H2O
# Experian)&nbsp;
#
# ARCGIS
# project management
# Cloud computing
# AWS S3
# NE
#
# TDWI
# Modelling
# As a Predictive Analytics
# SonarQube
# Bamboo
# OWASP ZAP
# Centrify
# Bash shell scripting
# Git CLI
# AWS NACL
# GitLab
# RocketChat
# Hyper-V
# the leader
# Streaming Analytics
# simulations
# Data Administrators
# Pytorch
# Spark MLlib
# query techniques
# RockCreek seeks a
# Multivariate regression
# Tensorflow experience
# T-sql
# Cox model
# Finance
#
# Nifi
# Neo4
# Machine/
# Prometheus SQL
# Amazon Redshift
# Supervised &amp;
# Anomaly Detection
# Optimization Algorithms
# MATLAB; DB &amp; Management
# Golang
# Relational DB
# .net
# Tele sales &amp; Retention
# Price Optimization
# modern Fortran
# andor AI
# South Austin
# PySpark
# R Markdown
# algorithms
# genetic algorithms
# SAS/SQL
# Manager
# Software Engineers
# Economic Researchers
# applied research
# Wellness Programs
# Shinyapps
# machine/deep learning
# Heights
# MO
#
# amp;
# Microsoft BI
# time series analysis
# NoSQL systems
# Data
# e.g. R
# Python analysis
# Flask
# SSRS
# through
# Information Systems
# service experts
# BI
# nlp
# the Chief Analytics Office
# Digital Sales
# SQL-like
# HP Vertica
# Master
# Machines learning
# +3
# perl
# cloud distributed computing
# linux/shell
# such
# Javascript and/or
# business analytics
# statistical software (R)
# Data/Customer Analytics
# At Civis
# CRO
# tensorflow
# collaborate
# Hypothesis Testing
# SAS analytics
# At Telnyx
# ancestry
# creed
# data science
# Nebraska
#
# common scripting
# Corporate Marketing
# IT
# database analytics
# no-SQL
# experimentation systems
# IT networks
# Ruby
# Fortran
# the Map-R
# technical support
# Teradata SQL Server
# Oracle SQL Server
# clickstream analysis
# SQL/NOSQL
# database systems
# technical leader
# HR
# No-SQL
# PeopleSoft
# SQL database
# Dynamo DB
# I4.0
# collegial team player
# Euro Accident
# surgical research
# TensorFlowDatabases
# Protected Veterans
# Amazon Aurora
# conducting predictive analytics
# Room 204
# including SQL
# Data ScienceJob
# relational SQL
# SQL ·
# JanusGraph
# CosmosDB
# Azure HDInsight
# Python / Django
# predictive analysis
# elfa
# D365
# Microsoft (NAV
# O365
# Account Management
# relational databases (e.g. SQL
# network protocols
# ------------------------------------------------------------------------ 4500
# business process
# computer science
# six sigma
# Position SQL Developer
# JS
# regex
# Dask
# using R
# social safety net
# Dask
#
# Populate SQL
# Team Player
# Operations Management
# PSLF
# Actuarial Research
# Julia
#
# VBScript
# Jupyter Notebook
# e.g. java
# Google
# Computer Sciences
# Neural Nets
# Engineering 2
# andMongoDB
# networks
# Pig
# Microsoft PowerPoint
# AWS ML
# PMML
# etc.-
# time series
# e.g. Hadoop
# such as Java
# Python SQL
# network,
# Windows
# decision engineering support
# MS PowerPoint
# CNTK
# systems engineering
# Office 365
# Microsoft Advertising
# Azure,
# Spark/SparkR
# HIVE
# Gaussian process
# machine intelligence
# IBM Analytics
# Data Processing
# Azure Experience
# As a System
# Network analysis
# Regression analysis
# Software
# Geospatial Analytics
# advanced statistical analysis
# team player
# consumer marketing
# sales
# A B.S.
# specifically R
# Java script
# NLP &amp
# Crop/Plant
# Windows 2003
# age
# six
# Software Engineer
# Business Intelligence Engineer
# Data Architect building
# AWS AI
# Google AI
# Medication Adherence
# ------------------------------------------------------------------------ 5000
# NLTK
#
# Michigan - 150k Location
# AWZ
# Spark/PySpark
# testing
# database querying
# R & SQL
# RDS
# Scala
# anomaly detection
# Bash Scripting
# Apache SOLR
# statistical software (R
# Comcast PABS
# Prescriptive Analytics
# MATLAB)Experience extracting
# Builds predictive and/or
# TX 75014
#
# Menlo Ventures
# Postgis
# PostgresSQL
# PgAdmin
# forecasting/predictive analytics
# strong SQL experience
# Gradient Boosting
# Qlikview Data visualization
# Manufacturing Analytics
# MRP
# stay abreast
# Enlighten IT Consulting
# javascript
# css
# as SQL
# Math or similar
# TX
#
# VIYA
# prescriptive analytics
# Data ScientistDescription
# seeking a
# We are
# Advanced Visualization
# database
# ------------------------------------------------------------------------ 5300
# Data ScientistPython
# Risk Analytics
# Data
#
# AWS Lambda
# -site
# html
# nginx
# Python Django apps
# MS Visual Studio
# CouchDB
# differential privacy algorithms
# Non-linear
# link analysis
# Multivariate regression
#
# financial analysis
# JMP
# Five
# Unix shell Scripting
# Spark
#
# Looker
# Google Cloud Composer
# GCP,
# PL/SQL/ MySQL
# Service Engineering Operations
# Data systems
# multivariate data analysis
# WE ARE
# TRANSFORMATIONAL PARTNER
# speech analytics
# application server
# ------------------------------------------------------------------------ 5600
# e.g Spark
# performance
# flow
# e.g Hadoop
# autonomous systems
# NFL
# Marketo
# query authoring
# JupyterHub
# e.g
# Institutional Research
# Teradata
#
# Statistical Model Development
# Presto
# seven
# IST Research
# Growth
# Messaging
# confluence
# mysql
# including Deep Learning
# Geospatial
# Digital Transformation
# Software/
# AUROC
# Medicare administrative
# Tableau and/or
# Performance Bonus
# Shell
# Data warehouse
# SDLC
# Shell scripting
# PL SQL
# Artificial Intelligence team.&nbsp;
#
# AngularJS
# Shell script
# Recursive Neural Networks frameworks
# database schema
# ------------------------------------------------------------------------ 6100
# team structure
# CRM systems
# web analytics
# Hallmark
# Pac-12 Networks
# NATIONAL ORIGIN
# microservice
# C2S
# episode analytics
# software development
# statistics
# ------------------------------------------------------------------------ 6200
# surgical planning
# Dimensional
# NoSql
# Data Engineer
# information retrieval
# Oracle Business Intelligence
# SCOPE
# Data Depiction
# tools
# predictive model
# a scripting
# Data Lakes
# Google Docs
# CodeCommit
# Glue
# Spring
# Jenkins)
# JEE
# DSC
# Columbus
# shell script
# Rstudio Connect
# Cognitive Computing
# AI/ML
# Telecom
# Jupyter NotebookExperience
# RapidMiner,
# DALLAS
# learning
# Automation (IA&A
# Strategic Analytics
# Design
# visualization tooling
# Risk Management
# analysis
# PyTorch (BERT)
# Gensim (word2vec
# - 11
# ------------------------------------------------------------------------ 6700
# Project Leader
# AWS Glue
# TX
#
# Advanced/Non-Standard
# Geospatial Developer
# management consulting
# including risk consulting
# HR Management
# DevOps;
#
# DOMO
# NumPy
# OpenNeuro
# ROI
# trend analysis
# Targeting
# ------------------------------------------------------------------------ 7100
# AutoML
# data bases
# hadoop
# NextFlow
# Up
# Statistic Modeling/Predictive Modeling/AI/Algorithms
# SAP BI Hana
# network design
# ensemble learning
# Data querying
# SQL MongoDB
# race, color
# credit bureaus
# Relational
# scientific computing
# advanced predictive
# Problem-solving
# seeking a sharp
# QUALIFICATIONS
#
# South Carolina
# Oklahoma
# Numerical Analysis
# Truckstop.com
#
# At Acorns
# Architecture
# Project Management
# Predictive analytics
# Deep learning frameworks
# MA
# statistical modelling
# Predictive Modelling
# Optimizat
#
# recommendation algorithms
# SQL Alchemy
# CARE
# graphics
# HTML5
# LINUX/UNIX OS
# Python CICD
# DevOps (Jenkins
# Eden Prairie
# Intel
# GLM Regression (linear
# data structures
# Microsoft Excel
# PowerPivot
# cognitive systems
# TX 75024 &
# Artificial Intelligence breakthroughs
# Data environmentOracle
# BigSQL
# SVN
# Java; querying
# The Cognitive
# data scientist
# Java/R
# ------------------------------------------------------------------------ 8000
# including Hadoop
# ------------------------------------------------------------------------ 8100
# /scripting
# Automation
#
# Data science
# Marlboro
# MA
#
# Operations Analytics
# Server Integration Services
# statistical tests
# GLM/regression
# years direct
# NY
# architecture (e.g. Cloud
# BIDS
# Advanced R
# Rm 135
# Advanced Google Analytics
# political affiliation
# database reporting
# database management system
# XMLor SQL
# Data Modelling
# HP Marketing
# My SQL
# PDF/CDF
# data scientists
# Advanced Python
# EXL
# EXL Analytics
# Provides support
# rates;
#
# CSSP
# Acquisition Analytics
# advanced statistical testing
# critical thinking
# ------------------------------------------------------------------------ 8400
# executive
# and/or SQL
# Azure streaming analytics
# Social Sciences
# Data scientist JD
# We are a
# -Predictive Analytics
# Data Cleaning
# MS-
# Visual analytics
# Presentation graphics
# audit
# Paso
# TX 88568
# GV
# Predictive Modeling &
# AWS &amp; Java
# problem scoping
# econometric analysis
# marketing analytics
# Design Thinking
# Matlab
#
# FastStructure
# ------------------------------------------------------------------------ 8600
# Space/SOSI
# EC2/ECS
# CircleCi
# TX 78716
#
# PR News
# Web analytics
# Training
#
# Google Cloud
#
# Job #NT13
# ------------------------------------------------------------------------ 8700
# A/B testing
# Python experience
# Automation
# digital advertising
# database marketing
# TX 75075
# HighCharts
# SQL Research
# Stan
# Open source
# Bugs
# SQL/Hive
# unit/integration testing
# svn
# Optimization R
# Training
# Advanced Reporting
# Chemistry
# statistical algorithms
# Non-SQL
# mechanics
# Econometrics
# Data Robot
# Data Architects
# Java Experience
# xgboost
# Data Integration and/or
# ACL
# required experience
# Manufacturing
# applying predictive analytics
# On 33
# MS degree
# SQL)
# Julia
#
# Series A
# prototyping systems
# Alberta
# Route 53
# Multiple Regression
# multivariate analytics
# Data & Analytics
# No
# NS3-15437212
# SQLData Visualization
# / Hadoop
# PyTorch
#
# AB testing
# AdOps
# computing
# Consumer Risk Management
# Banking
# XML Schema
# Extensive experience
# routing protocols
# cybersecurity
# and/or SQL Experience
# databases (SQL
# HTML/
# API integration
# Data Robot experience
# If R
# o R
# Pivotal Cloud Foundry
# algorithm analysis
# JDBC
# MS/MA
# C2S and/or
# Jason
# research analytics
# Model assessment
# Model building
# Reshift
# either R
# MapReduce/Hive
# machine / deep learning
# Data Studio
# ------------------------------------------------------------------------ 9300
# C and
# Tx
# ------------------------------------------------------------------------ 9400
# relational (
# integration frameworks
# Python/
# HP Autonomy
# Data integration
# artificial networks
# Google Ventures
# Andreessen Horowitz
# Microsoft
# architecture (e.g. Hadoop
# Sparkling Water
# We are a successful
# D
# Data Workbench
# Minimum
# Microsoft SQL server
# Lambda
# ------------------------------------------------------------------------ 9600
# advanced data analytics
# CI / CD
# advanced language
# .Net
# AJAX
# MuleSoft
# cloud architectures
# Techniques;
# Medical Data Analytics
# as
# strategic partnerships
# financial risk analytics
# web scraping
# target marketing
# Microsoft SQL Server Management Studio
# MA&S
# Bachelors
# Postgres / PostGIS
# systems
# At least
# SQL Python
# pymc Problem solving
# and shell scripting
# Memory Networks
# OpenShift
# 6
# experimentation (A/B testing
# Jupyter
#
# spark)
# python / R
# SQL and/or Cognos
# generic SQL
# jQuery Experience
# Marketing Science
# and/or Docker
# Microsoft Development
# Java HP Vertica TensorFlow
# Data Processing/Analytics
# An M.S.
# Deep Networks
# i.e. Python
# Microsoft AzureML
# graph analysis
# SAP predictive analytics
# ------------------------------------------------------------------------ 9800
# Google cloud
# network file systems
# query languages
# Microservices
# Mathematical Engineering
# develop Entry
# customer relationship management
# Vulnerability Management
# Postgres / Redshift
# DoJ
# DoE
# spam
# noSQL
# ------------------------------------------------------------------------ 9900
# such as R
# UNIX shell scripting
# media analytics
# SPLUS
# Statistical Modelling
# Reinforcement learning
# Team
#
# NPS

# %%
# skill_set = dict( Counter(skill_set).most_common(300) )
# skill_set

# %% [markdown]
# # ============================================================
# ## 基于句法分析抽取层级关系
#
# ### 根据每个技能类关键词，向上找最小分支树，判断依存关系

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def is_father( word, root ):
    if word == root:
        return True
    
    while word != word.head:
        word = word.head
        if word == root:
            return True
    
    return False

# %%
ind = 0

total_link_list = []
for root,dirs,files in os.walk(r"E:\dataset\dataset"):
    for file in files:
        ind += 1
#         if ind < 500:
#             continue
            
        if ind % 2 == 1:
            continue
        
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )

        my_string = my_file.readlines()
        for string_list in my_string[1:]:
            string_list = string_list.replace('e.g.','like')
            string_list = string_list.replace('.)',')')
#             for string in [sentence for sentence in re.split(r'[？?！!。；;：:\n\r·]', string_list) if sentence]:
            for string in re.split(r'[？?！!。.；;：:\n\r·•*]', string_list):
#                 try:
                doc = nlp( string )

                my_chunks_list = []
                roor_chunks_dict = {}

                for chunk in doc.noun_chunks:
                    if chunk.text in skill_set.keys():
                        my_chunks_list.append( chunk.root )
                        roor_chunks_dict[ str(chunk.root)] = str(chunk)

                if len( my_chunks_list ) > 1:
#                     print( 'skill word:', my_chunks_list )
                    Total_List = []

                    for word in my_chunks_list:
                        temp_list = []
                        temp_list.append(word)

                        pre = word
                        while word != word.head:
                            pre = word
                            relation = word.dep_
                            word = word.head

                            if 'N' in word.tag_ and (relation != 'conj' and relation != 'appos'):
                                if word in my_chunks_list:
                                    temp_list.append( word )

                                    if len( [str( roor_chunks_dict[str(w)] ) for w in temp_list if 'xperience' not in str(w)] ) == 2:
                                            print(string)
                                            print('result1:') 
                                            print( '-->'.join([str( roor_chunks_dict[str(w)] ) for w in temp_list]) )
                                            total_link_list.append( [str( roor_chunks_dict[str(w)] ) for w in temp_list] )
                                            print()

                                else:
                                    tree_list = []
                                    for t in my_chunks_list:
                                        if t.dep_ == 'compound' and is_father( t, word ) == True and is_father( t, pre ) == False:
                                            tree_list.append( t )

                                    if len(tree_list) == 1:
                                        key1 = roor_chunks_dict[ str(temp_list[0]) ]
                                        key2 = roor_chunks_dict[ str(tree_list[0]) ]
                                        
                                        if 'xperience' not in key1 and 'xperience' not in key2:
                                            print(string)
                                            print('result2:')  
                                            
                                            print( '-->'.join( [ key1, key2 ] ) )
                                            total_link_list.append( [ key1, key2 ] )
                                            print()
                                break
                
        my_file.close()

        if ind % 500 == 0:
            print( '==================================================',ind )
            
        if ind > 2000:
            break
# Out:
# Technology We Use
# result1:
# We-->Technology
#
#  You will develop models using algorithms for pattern detection and optimization
# result1:
# algorithms-->models
#
# Research in cryptomarket microstructure, including the fine details and mechanics of crypto exchanges, and their business
# result1:
# mechanics-->Research
#
#  Create visualizations in support of data science projects from beginning to end, including understanding the business need, understanding the analysis findings, prototyping models, and deploying completed models to deliver business impact to the organization, in collaboration with experienced data scientists
# result1:
# models-->prototyping
#
# - Experience developing software with C++, C, Java, Python, R, or Matlab, software applications in Linux, UNIX, Windows environments, data analysis algorithms, data management approaches, relational databases, or machine learning algorithms
# result1:
# algorithms-->machine learning
#
#    Tools such as Python (including Pandas, NumPy and Scikit-learn) and Tensorflow will be heavily leveraged
# result1:
# Pandas-->Python
#
#    Tools such as Python (including Pandas, NumPy and Scikit-learn) and Tensorflow will be heavily leveraged
# result1:
# NumPy-->Python
#
# Familiarity with graph, key value, and document data stores (like Neo4j, Hadoop, MongoDB) preferred
# result1:
# MongoDB-->Neo4j
#
#  Demonstrated experience with structuring data, natural language processing, database technologies, and machine learning algorithms
# result1:
# algorithms-->machine learning
#
#  Advanced skills and experience with R (required) and/or Python (desired) (including relevant packages) in support of advanced analytics Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas Expert-level logical and analytic skills Broad experience and solid theoretical foundation on the modeling process using a variety of algorithms Data profiling, distributions, confidence intervals, hypothesis testing Holdout for testing, cross-validation Data pre-processing, exploratory data analysis using a variety of techniques Regression and classification using linear models, GLMs, and tree-based methods Interpretation of model results, consideration of causality, treatment of multicollinearity Strong synthesis and presentation skills Experience with Teradata
# result1:
# SQL-->relational databases
#
#  6+ Months Contract Advanced skills and experience with R (required) and/or Python (desired) (including relevant packages) in support of advanced analytics Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas Expert-level logical and analytic skills Broad experience and solid theoretical foundation on the modelling process using a variety of algorithms Data profiling, distributions, confidence intervals, hypothesis testing Holdout for testing, cross-validation Data pre-processing, exploratory data analysis using a variety of techniques Regression and classification using linear models, GLMs, and tree-based methods Interpretation of model results, consideration of causality, treatment of multicollinearity Strong synthesis and presentation skills Experience with Teradata
# result1:
# SQL-->relational databases
#
#  problem formulation, requirements analysis, and planning Execute the full-scope of advanced analytic techniques Responsible for data surveying, profiling, and pre-processing Model data management for validation (like holdout, cross-validation) Selection of appropriate algorithms and execution Responsible for interpretation of results – for both causal inferences and predictive effectiveness Synthesize appropriate recommendations for action and changes Present findings, suggested actions and changes to a broad audience, and help manage follow-ups and execution Help teach and explain techniques and tools used to a broad set of business-intelligence, data, and analytics professionals with varied backgrounds Suggest tools, approaches, and data used to meet the needs of the particular problem REQUIRED QUALIFICATIONS Skills/Abilities and Knowledge Advanced skills and experience with R (required) and/or Python (desired) (including relevant packages) in support of advanced analytics Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas Expert-level logical and analytic skills Broad experience and solid theoretical foundation on the modeling process using a variety of algorithms Data profiling, distributions, confidence intervals, hypothesis testing Holdout for testing, cross-validation Data pre-processing, exploratory data analysis using a variety of techniques Regression and classification using linear models, GLMs, and tree-based methods Interpretation of model results, consideration of causality, treatment of multicollinearity Strong synthesis and presentation skills Experience with Teradata
# result1:
# SQL-->relational databases
#
#  Deployment of proof of concepts using advanced analytics, like algorithms in Java, J2EE, SAS, SPSS, Python, R, VBA, Excel, and other tools as required by the client’s problem and environment
# result1:
# advanced analytics-->concepts
#
#  Examples projects include optimization of lead generation systems using machine learning techniques and building recommendation systems for personalized user content
# result1:
# recommendation systems-->optimization
#
# ================================================== 500
# Experience with statistical software or scientific computation software (like,R, Matlab) is preferred
# result1:
# R-->statistical software
#
# Experience with statistical software or scientific computation software (like,R, Matlab) is preferred
# result1:
# Matlab-->statistical software
#
#  Performing data visualization using R Shiny, Spotfire or Tableau
# result1:
# Spotfire-->data visualization
#
#  Performing data visualization using R Shiny, Spotfire or Tableau
# result1:
# Tableau-->data visualization
#
#  and launch, monitor, and evaluate experiments and A/B tests Requirements 3+ years of experience (5+ preferred) in quantitative analysis or data science Strong understanding of methods in statistical analysis (like, supervised machine learning methods, hypothesis testing, etc) Strong problem solving skills, with experience breaking down a large problem into smaller, solvable components Strong skills in data extraction and transformation with SQL Strong skills in data exploration, analysis, and visualization with Python or R Experience with BI and data visualization tools like Looker, Chartio, or Tableau Ability to initiate and drive projects to completion Excellent written and verbal communication skills
# result1:
# hypothesis testing-->analysis
#
#  Superior analytical skills with working knowledge of basic statistical, predictive and optimization models Experience in leading and managing data science teams Strong programming proficiency and working experience (10+years) in a subset of Python, R, Scala, Java (Python preferred) Strong proficiency and experience (10+ years) with data science and machine learning software stacks, like NumPy, Pandas, SK-learn for Python Programming proficiency in Spark and MLlib (3+ years) Working experience with and understanding of large-scale data analysis systems, like Hadoop or MPP databases (5+ years) Proficiency and experience with SQL (10+ years) Significant experience (10+ years) implementing machine learning and data science models, including through production Strong theoretical and practical knowledge of machine learning models and algorithms (unsupervised and supervised), their use in applications, and their advantages and disadvantages Strong knowledge of code-based data visualization tools (like matplotlib) for data exploration and to present models and results to internal and external stakeholders Experience with cloud-based systems and toolsets (3+ years) Experience and understanding of experiment design and evaluation Knowledge of big data engineering toolsets a plus Superior data preparation skills
# result1:
# Python-->Java
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# predictive modeling-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# machine learning-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# simulation-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# optimization-->advanced analytics
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# predictive modeling-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# machine learning-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# simulation-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# optimization-->advanced analytics
#
# Experience working with tools including object-oriented programming (Python, Java), computational analysis tools (R, MATLAB), and associated data science libraries (scikit-learn)
# result1:
# Python-->tools
#
#  Very good querying skills for feature creation Exposure or willingness to deploy models using TensorFlow, Keras, Edward, etc
# result1:
# TensorFlow-->models
#
#  Very good querying skills for feature creation Exposure or willingness to deploy models using TensorFlow, Keras, Edward, etc
# result1:
# Keras-->models
#
# Minimum of ten (10) years of operational experience with Linux systems to include architecture, deployment, operational management, and analysis of security information systems
# result1:
# architecture-->Minimum
#
# Minimum of ten (10) years of operational experience with Linux systems to include architecture, deployment, operational management, and analysis of security information systems
# result1:
# analysis-->Minimum
#
# Proficiency in data manipulation and machine learning using Python or R or H2O
# result1:
# Python-->learning
#
# Proficiency in data manipulation and machine learning using Python or R or H2O
# result1:
# R-->learning
#
# Proficiency in data manipulation and machine learning using Python or R or H2O
# result1:
# H2O-->learning
#
# Proficiency in data manipulation and machine learning using Python or R or H2O
# result1:
# Python-->learning
#
# Proficiency in data manipulation and machine learning using Python or R or H2O
# result1:
# R-->learning
#
# Proficiency in data manipulation and machine learning using Python or R or H2O
# result1:
# H2O-->learning
#
# Prior experience working with databases (like, Oracle, MySQL, SQL Server, MongoDB)
# result1:
# MySQL-->databases
#
# Deep expertise in analyzing large, complex, multi-dimensional data sets with combination of tools, including SQL and other ETL tools
# result1:
# SQL-->tools
#
# Excellent knowledge of machine learning algorithms
# result1:
# algorithms-->machine learning
#
# Experience with statistical software (like, R, Python, Julia, MATLAB, pandas) and database languages (like, SQL)
# result1:
# R-->statistical software
#
# Experience with statistical software (like, R, Python, Julia, MATLAB, pandas) and database languages (like, SQL)
# result1:
# Python-->statistical software
#
# Experience with statistical software (like, R, Python, Julia, MATLAB, pandas) and database languages (like, SQL)
# result1:
# Julia-->statistical software
#
# Experience with statistical software (like, R, Python, Julia, MATLAB, pandas) and database languages (like, SQL)
# result1:
# MATLAB-->statistical software
#
#  -5+ years of experience as a data scientist -Experience with building statistical models and developing machine learning algorithms -Experience with managing a data scientist team -Experience with programming languages, including Python, R, Scala, or Java -Experience with big data technologies, including HDFS, Hadoop, or Spark -Experience with deep learning paradigms and frameworks -Experience with manipulating data and ETL in parallel processing and distributed compute environments -Experience with designing and executing machine learning models and applications -TS/SCI clearance -MA or MS degree Clearance
# result1:
# algorithms-->machine learning
#
# Experience with building statistical models and developing machine learning algorithms
# result1:
# algorithms-->machine learning
#
# Experience with data visualization and programming languages, including Python, R, Scala, or Java
# result1:
# Python-->data visualization
#
# Experience with data visualization and programming languages, including Python, R, Scala, or Java
# result1:
# R-->data visualization
#
# Experience with data visualization and programming languages, including Python, R, Scala, or Java
# result1:
# Scala-->data visualization
#
# Experience with data visualization and programming languages, including Python, R, Scala, or Java
# result1:
# Java-->data visualization
#
#  Bring your unique self to Cisco, where you'll join with the best people to help Cisco change the way the world lives, plays, works and le
# result1:
# Cisco-->Cisco
#
#  Bring your unique self to Cisco, where you'll join with the best people to help Cisco change the way the world lives, plays, works and le
# result1:
# Cisco-->Cisco
#
# ================================================== 1000
#    Responsibilities The Data Scientist II has primary responsibility for conducting data science projects with applications in assessment and learning analytics and technologies, including automated scoring
# result1:
# analytics-->learning
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# Word-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# Excel-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# SQL Server-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# PowerPoint-->MS Office
#
# Minimum of 1 year statistical and other tools languages SAS, C, C , Java, Python
# result1:
# Python-->Minimum
#
# Knowledge in predictive analytics using tools such as R, Python and SAS
# result1:
# tools-->predictive analytics
#
#  consulting with clients to understand their data context and goals, creating and delivering training curriculum on Data Science best practices, exploring data to determine the feasibility and viability of modeling, and developing models using Machine Learning and other algorithmic methods
# result1:
# Machine Learning-->models
#
#  Conducts advanced analytics leveraging predictive modeling, machine learning, data mining, data visualization, simulation, and optimization
# result1:
# predictive modeling-->advanced analytics
#
#  Conducts advanced analytics leveraging predictive modeling, machine learning, data mining, data visualization, simulation, and optimization
# result1:
# machine learning-->advanced analytics
#
#  Conducts advanced analytics leveraging predictive modeling, machine learning, data mining, data visualization, simulation, and optimization
# result1:
# data mining-->advanced analytics
#
#  Conducts advanced analytics leveraging predictive modeling, machine learning, data mining, data visualization, simulation, and optimization
# result1:
# data visualization-->advanced analytics
#
#  Conducts advanced analytics leveraging predictive modeling, machine learning, data mining, data visualization, simulation, and optimization
# result1:
# simulation-->advanced analytics
#
#  Conducts advanced analytics leveraging predictive modeling, machine learning, data mining, data visualization, simulation, and optimization
# result1:
# optimization-->advanced analytics
#
#  Advanced proficiency in Microsoft Office, including Word, Excel and PowerPoint is required
# result1:
# Word-->Microsoft Office
#
#  Advanced proficiency in Microsoft Office, including Word, Excel and PowerPoint is required
# result1:
# Excel-->Microsoft Office
#
#  Advanced proficiency in Microsoft Office, including Word, Excel and PowerPoint is required
# result1:
# PowerPoint-->Microsoft Office
#
# Support research to understand and improve automated scoring performance
# result1:
# research-->Support
#
# Knowledge of all phases of software development including design, coding, testing, debugging, implementation, and support
# result1:
# testing-->software development
# Advanced-level skills with relational databases, including SQL and utilizing data stored in complex schemas
# result1:
# SQL-->relational databases
#
# Design and Implementation of refinery data product using Spark, Map-Reduce, Hive, HDFS, Spring, Hibernate and Java
# result1:
# Spark-->Design
#
# Design and implementation of data product on Hadoop using Titan, Tinker-pop, HBase, Gremlin and Java
# result1:
# Java-->Design
#
# Knowledge of statistics including hypothesis testing
# result1:
# hypothesis testing-->statistics
#
# Statistical analysis, using SAS, R, Python or equivalent
# result1:
# SAS-->Statistical analysis
#
# Statistical analysis, using SAS, R, Python or equivalent
# result1:
# R-->Statistical analysis
#
# Statistical analysis, using SAS, R, Python or equivalent
# result1:
# Python-->Statistical analysis
#
# -Understanding of predictive analytics techniques leveraging machine learning algorithms
# result1:
# algorithms-->machine learning
#
#  Candidates should be fluent in Python for analytics including, Pandas, Numpy, Scipy, Scikit-learn, etc
# result1:
# Pandas-->analytics
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# learning-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# learning-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# data mining-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# database-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# data engineering-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# learning-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# visualization-->computer science
#
#  Employ techniques and theories within mathematics, statistics, operations research, information science, and computer science, including distributed processing, signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, and high-performance computing
# result1:
# predictive analytics-->computer science
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# R-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# SAS-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# Scala-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# MATLAB-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# Python-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# R-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# SAS-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# Scala-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# MATLAB-->scripting
#
# Experience with tools for data mining, statistics, analysis, and scripting (like, R, SAS, Scala, MATLAB, Python, Ruby)
# result1:
# Python-->scripting
#
# ================================================== 1500
# Design and develop models and algorithms that drive performance and provide insights, from prototyping to production deployment, across key areas of interest (like, APD optimization, Load Factor optimization, Cabin mix, channel mix)
# result1:
# performance-->models
#
# Academic/ project experience working with databases (like, Oracle, MySQL, SQL Server, MongoDB)
# result1:
# MySQL-->databases
#
# Experience with source control and dependency management software, including Git or Maven
# result1:
# Git-->source control
#
# Experience with source control and dependency management software, including Git or Maven
# result1:
# Git-->source control
#
# Familiarity with graph, key value, and document data stores (like Neo4j, Hadoop, MongoDB) preferred
# result1:
# MongoDB-->Neo4j
#
# Familiarity with graph, key value, and document data stores (like Neo4j, Hadoop, MongoDB) preferred
# result1:
# MongoDB-->Neo4j
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# Word-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# Excel-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# SQL Server-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# PowerPoint-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# Word-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# Excel-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# SQL Server-->MS Office
#
# Minimum of 2 years of MS Office including Word, Excel, SQL Server, and PowerPoint
# result1:
# PowerPoint-->MS Office
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# predictive modeling-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# machine learning-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# simulation-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# optimization-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# predictive modeling-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# machine learning-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# simulation-->advanced analytics
#
# Conducts advanced analytics leveraging predictive modeling, machine learning, simulation, optimization and other techniques to deliver insights or develop analytical solutions to achieve business objectives
# result1:
# optimization-->advanced analytics
#
#   The Data Scientist shall develop data analytics tools that automates data retrieval from multiple resources in different locations and performs data analysis including artificial intelligence (AI), machine learning (ML) and nature language processing (NLP), aiming at facilitating drug application review
# result1:
# artificial intelligence-->data analysis
#
#   The Data Scientist shall develop data analytics tools that automates data retrieval from multiple resources in different locations and performs data analysis including artificial intelligence (AI), machine learning (ML) and nature language processing (NLP), aiming at facilitating drug application review
# result1:
# AI-->data analysis
#
#   The Data Scientist shall develop data analytics tools that automates data retrieval from multiple resources in different locations and performs data analysis including artificial intelligence (AI), machine learning (ML) and nature language processing (NLP), aiming at facilitating drug application review
# result1:
# machine learning-->data analysis
#
#   The Data Scientist shall develop data analytics tools that automates data retrieval from multiple resources in different locations and performs data analysis including artificial intelligence (AI), machine learning (ML) and nature language processing (NLP), aiming at facilitating drug application review
# result1:
# ML-->data analysis
#
#   The Data Scientist shall develop data analytics tools that automates data retrieval from multiple resources in different locations and performs data analysis including artificial intelligence (AI), machine learning (ML) and nature language processing (NLP), aiming at facilitating drug application review
# result1:
# NLP-->data analysis
#
# Knowledge of statistics including hypothesis testing
# result1:
# hypothesis testing-->statistics
#
# Knowledge of statistics including hypothesis testing
# result1:
# hypothesis testing-->statistics
#
#  Demonstrated experience with structuring data, natural language processing, database technologies, and machine learning algorithms
# result1:
# algorithms-->machine learning
#
#   Four years (within the last seven years) experience conducting predictive analytics using data science (big data) and providing advice on relevant issues in the field of data science
# result1:
# data science-->predictive analytics
#
# Experience with relational (SQL Server, Oracle, MySQL, PostgreSQL) and NoSQL (Elastic Search, HBase) databases
# result1:
# MySQL-->SQL Server
#
# Experience with relational (SQL Server, Oracle, MySQL, PostgreSQL) and NoSQL (Elastic Search, HBase) databases
# result1:
# MySQL-->SQL Server
#
# Strong experience with data science - including building models, testing, analyzing, etc
# result1:
# testing-->data science
#
# Knowledge of statistics including hypothesis testing
# result1:
# hypothesis testing-->statistics
#
# Knowledge of statistics including hypothesis testing
# result1:
# hypothesis testing-->statistics
#
#  You will have an opportunity to work in roles such as Data Scientist, Data Engineer, or Chief Data Officer covering all aspects of Data including Data Management, Data Governance, Data Intelligence, Knowledge Graphs, and IoT
# result1:
# Data Management-->Data
#
#  You will have an opportunity to work in roles such as Data Scientist, Data Engineer, or Chief Data Officer covering all aspects of Data including Data Management, Data Governance, Data Intelligence, Knowledge Graphs, and IoT
# result1:
# Data Governance-->Data
#
#  You will have an opportunity to work in roles such as Data Scientist, Data Engineer, or Chief Data Officer covering all aspects of Data including Data Management, Data Governance, Data Intelligence, Knowledge Graphs, and IoT
# result1:
# Data Intelligence-->Data
#
#  You will have an opportunity to work in roles such as Data Scientist, Data Engineer, or Chief Data Officer covering all aspects of Data including Data Management, Data Governance, Data Intelligence, Knowledge Graphs, and IoT
# result1:
# IoT-->Data
#
#  -Experience with natural language processing -Experience with solutions for full-text search, hit highlighting, and faceted search, including SOLR or ElasticSearch -Experience with Agile methodology and software development -Experience with Cloud service providers (CSPs), including Amazon Web Services (AWS) and Azure -Knowledge of RESTful services design, development, and testing -Knowledge of at least one scripting language, including JavaScript, Node, Python, or Bash -Knowledge of object-oriented programming, including Java and C++ Clearance
# result1:
# Java-->JavaScript
#
#  -Experience with quantitative analysis and using databases -Experience with writing analytics to answer business or mission problems -Experience with scripting or scientific languages and software including Python, R, or MATLAB -TS/SCI clearance with a polygraph -BA or BS degree in Data Science, Statistics, CS, or Applied Mathematics Nice If You Have
# result1:
# Python-->scripting
#
#  -Experience with quantitative analysis and using databases -Experience with writing analytics to answer business or mission problems -Experience with scripting or scientific languages and software including Python, R, or MATLAB -TS/SCI clearance with a polygraph -BA or BS degree in Data Science, Statistics, CS, or Applied Mathematics Nice If You Have
# result1:
# R-->scripting
#
#  -Experience with quantitative analysis and using databases -Experience with writing analytics to answer business or mission problems -Experience with scripting or scientific languages and software including Python, R, or MATLAB -TS/SCI clearance with a polygraph -BA or BS degree in Data Science, Statistics, CS, or Applied Mathematics Nice If You Have
# result1:
# Python-->scripting
#
#  -Experience with quantitative analysis and using databases -Experience with writing analytics to answer business or mission problems -Experience with scripting or scientific languages and software including Python, R, or MATLAB -TS/SCI clearance with a polygraph -BA or BS degree in Data Science, Statistics, CS, or Applied Mathematics Nice If You Have
# result1:
# R-->scripting
#
#  -4 years of experience with conducting predictive analysis using data science, including Big Data and advising on relevant issues in the data science field -Experience working in the international relations and security studies areas -Experience with preparing and developing briefings, background papers, reports, and speeches for Flag or General Officers or the civilian equivalent -Active Secret clearance -MA degree Nice If You Have
# result1:
# Big Data-->data science
# ================================================== 2000

# %%
ind = 0

total_link_list = []
for root,dirs,files in os.walk(r"E:\dataset\dataset"):
    for file in files:
        ind += 1
        
        my_file = open( os.path.join(root,file),encoding = 'utf-8' )

        my_string = my_file.readlines()
        for string_list in my_string[1:]:
            string_list = string_list.replace('e.g.','like')
            string_list = string_list.replace('.)',')')
#             for string in [sentence for sentence in re.split(r'[？?！!。；;：:\n\r·]', string_list) if sentence]:
            for string in re.split(r'[ -？?！!。.；;：:\n\r·•*]', string_list):
#                 try:
                doc = nlp( string )

                my_chunks_list = []
                roor_chunks_dict = {}

                for chunk in doc.noun_chunks:
                    if chunk.text in skill_set.keys():
                        my_chunks_list.append( chunk.root )
                        roor_chunks_dict[ str(chunk.root)] = str(chunk)

                if len( my_chunks_list ) > 1:
#                     print( 'skill word:', my_chunks_list )
                    Total_List = []

                    for word in my_chunks_list:
                        temp_list = []
                        temp_list.append(word)

                        pre = word
                        while word != word.head:
                            pre = word
                            relation = word.dep_
                            word = word.head

                            if 'N' in word.tag_ and (relation != 'conj' and relation != 'appos'):
                                if word in my_chunks_list:
                                    temp_list.append( word )

                                    if len( [str( roor_chunks_dict[str(w)] ) for w in temp_list if 'xperience' not in str(w)] ) == 2:
                                            print( '-->'.join([str( roor_chunks_dict[str(w)] ) for w in temp_list]) )
                                            total_link_list.append( [str( roor_chunks_dict[str(w)] ) for w in temp_list] )

                                else:
                                    tree_list = []
                                    for t in my_chunks_list:
                                        if t.dep_ == 'compound' and is_father( t, word ) == True and is_father( t, pre ) == False:
                                            tree_list.append( t )

                                    if len(tree_list) == 1:
                                        key1 = roor_chunks_dict[ str(temp_list[0]) ]
                                        key2 = roor_chunks_dict[ str(tree_list[0]) ]
                                        
                                        if 'xperience' not in key1 and 'xperience' not in key2:
                                            print( '-->'.join( [ key1, key2 ] ) )
                                            total_link_list.append( [ key1, key2 ] )
                                break
                                    
        my_file.close()

        if ind % 500 == 0:
            print( '==================================================',ind )

# %%
link_df = pd.DataFrame( total_link_list )
link_df = link_df.rename(columns = {0:'node1',1:'node2'})
link_df
# Out:
#           node1                node2
# 0       Tableau   data visualization
# 1    algorithms        Deep learning
# 2       Tableau   data visualization
# 3    algorithms               models
# 4      business  advanced algorithms
# ..          ...                  ...
# 898  algorithms        deep learning
# 899  algorithms     machine learning
# 900  algorithms     machine learning
# 901  algorithms     machine learning
# 902  algorithms     machine learning
#
# [903 rows x 2 columns]

# %% [markdown]
# # 关系绘制

# %%
from unittest.mock import patch
from nose.tools import assert_equal, assert_in
from pyecharts import options as opts
from pyecharts.charts.basic_charts.graph import Graph

from pyecharts import options as opts
from pyecharts.charts import Graph

nodes = []
links = []

nodes_set = []

for ind, row in link_df.iterrows():
    
    if row['node1'] != row['node2']:
        
        if row['node1'] not in nodes_set:
            nodes_set.append( row['node1'] )
            nodes.append( {'name': row['node1'] , "symbolSize": 15 + skill_set[row['node1']] / 20 } )
            
        if row['node2'] not in nodes_set:
            nodes_set.append( row['node2'] )
            nodes.append( {'name': row['node2'] , "symbolSize": 15 + skill_set[row['node2']] / 20 } )
        
        links.append({"source": row['node2'], "target": row['node1']})

Graph().add(
    "", 
    nodes, 
    links, 
    repulsion=8000,
#     linestyle_opts=opts.LineStyleOpts(width=2, curve=0.1, opacity=0.9),
    linestyle_opts=opts.LineStyleOpts(width=0.5, curve=0.3, opacity=0.7),
    label_opts=opts.LabelOpts( ),
    categories=None,
    is_focusnode=True,
#     layout="none",
    is_roam=True
    
).set_global_opts(title_opts=opts.TitleOpts(title="")).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="7a8473162da74627903277f3b2f5fa6c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_7a8473162da74627903277f3b2f5fa6c = echarts.init(
#                     document.getElementById('7a8473162da74627903277f3b2f5fa6c'), 'white', {renderer: 'canvas'});
#                 var option_7a8473162da74627903277f3b2f5fa6c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "graph",
#             "layout": "force",
#             "symbolSize": 10,
#             "circular": {
#                 "rotateLabel": false
#             },
#             "force": {
#                 "repulsion": 8000,
#                 "edgeLength": 50,
#                 "gravity": 0.2
#             },
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 0.5,
#                 "opacity": 0.7,
#                 "curveness": 0.3,
#                 "type": "solid"
#             },
#             "roam": true,
#             "draggable": false,
#             "focusNodeAdjacency": true,
#             "data": [
#                 {
#                     "name": "Tableau",
#                     "symbolSize": 17.2
#                 },
#                 {
#                     "name": "data visualization",
#                     "symbolSize": 15.2
#                 },
#                 {
#                     "name": "algorithms",
#                     "symbolSize": 15.1
#                 },
#                 {
#                     "name": "Deep learning",
#                     "symbolSize": 15.35
#                 },
#                 {
#                     "name": "models",
#                     "symbolSize": 16.3
#                 },
#                 {
#                     "name": "business",
#                     "symbolSize": 15.1
#                 },
#                 {
#                     "name": "advanced algorithms",
#                     "symbolSize": 15.1
#                 },
#                 {
#                     "name": "prototyping",
#                     "symbolSize": 15.15
#                 },
#                 {
#                     "name": "Excel",
#                     "symbolSize": 19.7
#                 },
#                 {
#                     "name": "Microsoft Office",
#                     "symbolSize": 16.9
#                 },
#                 {
#                     "name": "Word",
#                     "symbolSize": 15.75
#                 },
#                 {
#                     "name": "PowerPoint",
#                     "symbolSize": 17.85
#                 },
#                 {
#                     "name": "Python",
#                     "symbolSize": 77.15
#                 },
#                 {
#                     "name": "Java",
#                     "symbolSize": 31.75
#                 },
#                 {
#                     "name": "deep learning",
#                     "symbolSize": 20.35
#                 },
#                 {
#                     "name": "machine learning",
#                     "symbolSize": 30.15
#                 },
#                 {
#                     "name": "Pandas",
#                     "symbolSize": 15.2
#                 },
#                 {
#                     "name": "MongoDB",
#                     "symbolSize": 16.85
#                 },
#                 {
#                     "name": "Neo4j",
#                     "symbolSize": 15.05
#                 },
#                 {
#                     "name": "SQL",
#                     "symbolSize": 55.75
#                 },
#                 {
#                     "name": "relational databases",
#                     "symbolSize": 15.05
#                 },
#                 {
#                     "name": "recommendation systems",
#                     "symbolSize": 15.1
#                 },
#                 {
#                     "name": "optimization",
#                     "symbolSize": 15.7
#                 },
#                 {
#                     "name": "automation",
#                     "symbolSize": 15.1
#                 },
#                 {
#                     "name": "reporting",
#                     "symbolSize": 15.05
#                 },
#                 {
#                     "name": "predictive modeling",
#                     "symbolSize": 15.45
#                 },
#                 {
#                     "name": "advanced analytics",
#                     "symbolSize": 15.8
#                 },
#                 {
#                     "name": "hypothesis testing",
#                     "symbolSize": 15.65
#                 },
#                 {
#                     "name": "statistical analysis",
#                     "symbolSize": 15.35
#                 },
#                 {
#                     "name": "Spotfire",
#                     "symbolSize": 15.2
#                 },
#                 {
#                     "name": "TensorFlow",
#                     "symbolSize": 18.25
#                 },
#                 {
#                     "name": "Keras",
#                     "symbolSize": 16.25
#                 },
#                 {
#                     "name": "Spark",
#                     "symbolSize": 28.2
#                 },
#                 {
#                     "name": "distributed computing",
#                     "symbolSize": 15.05
#                 },
#                 {
#                     "name": "MySQL",
#                     "symbolSize": 18.1
#                 },
#                 {
#                     "name": "databases",
#                     "symbolSize": 16.2
#                 },
#                 {
#                     "name": "NoSQL",
#                     "symbolSize": 21.45
#                 },
#                 {
#                     "name": "research",
#                     "symbolSize": 15.7
#                 },
#                 {
#                     "name": "R",
#                     "symbolSize": 51.9
#                 },
#                 {
#                     "name": "Scala",
#                     "symbolSize": 15.1
#                 },
#                 {
#                     "name": "predictive analytics",
#                     "symbolSize": 16.0
#                 },
#                 {
#                     "name": "MS Office",
#                     "symbolSize": 17.1
#                 },
#                 {
#                     "name": "SQL Server",
#                     "symbolSize": 16.5
#                 },
#                 {
#                     "name": "statistics",
#                     "symbolSize": 15.25
#                 },
#                 {
#                     "name": "Machine Learning",
#                     "symbolSize": 39.25
#                 },
#                 {
#                     "name": "medical condition",
#                     "symbolSize": 15.15
#                 },
#                 {
#                     "name": "national origin",
#                     "symbolSize": 15.65
#                 },
#                 {
#                     "name": "Support",
#                     "symbolSize": 15.05
#                 },
#                 {
#                     "name": "PyTorch",
#                     "symbolSize": 15.25
#                 },
#                 {
#                     "name": "machine learning frameworks",
